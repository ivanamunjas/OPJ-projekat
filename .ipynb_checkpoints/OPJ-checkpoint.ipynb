# %%
import pandas as pd 
import numpy as np
import re

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def create_common_df(id_):
    try:
        cols = ['NaturalLanguageID', 'ProgrammingLanguageName', 'RepoID', 'SourceID', 'CommentID', 'comment', 'label']
        df = pd.read_csv('C:\\Users\\ASUS\\Desktop\\ETF\\V\\OPJ\\Data\\Common\\OutDataCommon{}.txt'.format(id_), sep='\t', lineterminator='\r', header=None)
        df.columns = cols
        df = df.drop(['NaturalLanguageID', 'ProgrammingLanguageName', 'RepoID', 'SourceID', 'CommentID'],axis=1)
        return df
    except:
        with open('C:\\Users\\ASUS\\Desktop\\ETF\\V\\OPJ\\Data\\Common\OutDataCommon{}.txt'.format(id_), "r", encoding="utf-8",  newline="\r\n") as source:
            for line in source:
                line = line.replace("\n", "")
                part = line.split("\t")
                if len(part) != 7:
                    print('POPRAVITI .TXT')
                    print(part)

# %%
df1 = create_common_df(1)
df2 = create_common_df(2)
df3 = create_common_df(3)
df4 = create_common_df(4)

# %%
df4.shape
# Out:
# (557, 2)

# %%
pd.set_option('display.max_rows', 10)

# %%
merged = df1.merge(df2, how='left', on='comment', suffixes=('_1', '_2')).merge(df3, how='left', on='comment').merge(df4, how='left', on='comment')

# %%
cols = merged.columns.values
cols[3] = 'label_3'
cols[4] = 'label_4'
merged.columns = cols

# %%
merged.drop_duplicates(subset ="comment", keep = False, inplace = True)
merged = merged.dropna()
merged = merged.reset_index(drop=True)

# %%
hits = np.zeros((merged.shape[0],6))

for i in range(merged.shape[0]):
    if merged.loc[i]['label_1'] == merged.loc[i]['label_2']:
        hits[i][0] += 1
    if merged.loc[i]['label_1'] == merged.loc[i]['label_3']:
        hits[i][1] += 1
    if merged.loc[i]['label_1'] == merged.loc[i]['label_4']:
        hits[i][2] += 1
    if merged.loc[i]['label_2'] == merged.loc[i]['label_3']:
        hits[i][3] += 1
    if merged.loc[i]['label_2'] == merged.loc[i]['label_4']:
        hits[i][4] += 1
    if merged.loc[i]['label_3'] == merged.loc[i]['label_4']:
        hits[i][5] += 1

# %%
all_same = 0
three_same_one_diff = 0
two_same_two_diff = 0
two_same_one_diff_one_diff = 0
all_diff = 0

for i in range(hits.shape[0]):
    if hits[i].sum() == 6:
        all_same += 1 
    if hits[i].sum() == 3:
        three_same_one_diff += 1
    if hits[i].sum() == 2:
        two_same_two_diff += 1
        
    if hits[i].sum() == 1:
        two_same_one_diff_one_diff += 1
    if hits[i].sum() == 0:
        all_diff += 1

# %%
print('All same: ', all_same)
print('Three same, one different: ', three_same_one_diff)
print('Two same, two different (same to one another): ', two_same_two_diff)
print('Two same, two different (different from one another): ', two_same_one_diff_one_diff)
print('All different: ', all_diff)
print('Total comments: ', merged.shape[0])
# Out:
# All same:  354
# Three same, one different:  95
# Two same, two different (same to one another):  12
# Two same, two different (different from one another):  14
# All different:  1
# Total comments:  476

# %%
print('All same (%): ', round(all_same/merged.shape[0]*100))
print('Three same, one different (%): ',  round(three_same_one_diff/merged.shape[0]*100))
print('Two same, two different (same to one another) (%): ',  round(two_same_two_diff/merged.shape[0]*100))
print('Two same, two different (different from one another) (%): ',  round(two_same_one_diff_one_diff/merged.shape[0]*100))
print('All different (%): ',  round(all_diff/merged.shape[0]*100))
# Out:
# All same (%):  74
# Three same, one different (%):  20
# Two same, two different (same to one another) (%):  3
# Two same, two different (different from one another) (%):  3
# All different (%):  0

# %%
print('Procenat podudarnosti izmedju Laze i Matije: ', round(hits[:,0].sum()/merged.shape[0]*100))
print('Procenat podudarnosti izmedju Laze i Mateje: ', round(hits[:,1].sum()/merged.shape[0]*100))
print('Procenat podudarnosti izmedju Laze i Munje: ', round(hits[:,2].sum()/merged.shape[0]*100))
print('Procenat podudarnosti izmedju Matije i Mateje: ', round(hits[:,3].sum()/merged.shape[0]*100))
print('Procenat podudarnosti izmedju Matije i Munje: ', round(hits[:,4].sum()/merged.shape[0]*100))
print('Procenat podudarnosti izmedju Mateje i Munje: ', round(hits[:,5].sum()/merged.shape[0]*100))
# Out:
# Procenat podudarnosti izmedju Laze i Matije:  87.0
# Procenat podudarnosti izmedju Laze i Mateje:  93.0
# Procenat podudarnosti izmedju Laze i Munje:  83.0
# Procenat podudarnosti izmedju Matije i Mateje:  89.0
# Procenat podudarnosti izmedju Matije i Munje:  78.0
# Procenat podudarnosti izmedju Mateje i Munje:  83.0

# %% [markdown]
# ## Priprema common podataka za dodavanje celokupnim podacima

# %%
cols = ['NaturalLanguageID', 'ProgrammingLanguageName', 'RepoID', 'SourceID', 'CommentID', 'comment', 'label']
df = pd.read_csv('C:\\Users\\ASUS\\Desktop\\ETF\\V\\OPJ\\Data\\Common\OutDataCommon1.txt', sep='\t', lineterminator='\r', header=None)
df.columns = cols

# %%
for i in range(df.shape[0]):
    if df['NaturalLanguageID'][i][0] == '\n':
        df['NaturalLanguageID'][i] = df['NaturalLanguageID'][i][1:]

# %%
df
# Out:
#     NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                  SR                    Java  BILD-IT-Advanced-master
# 1                  SR                    Java  BILD-IT-Advanced-master
# 2                  SR                    Java  BILD-IT-Advanced-master
# 3                  SR                    Java  BILD-IT-Advanced-master
# 4                  SR                    Java  BILD-IT-Advanced-master
# ..                ...                     ...                      ...
# 587                SR                    Java               SBZ-master
# 588                SR                    Java        SCStemmers-master
# 589                SR                    Java        SCStemmers-master
# 590                SR                    Java        SCStemmers-master
# 591                SR                    Java        SCStemmers-master
#
#                                               SourceID  \
# 0        src\grupniProjekat_HotelManagement\Hotel.java
# 1        src\grupniProjekat_HotelManagement\Hotel.java
# 2        src\grupniProjekat_HotelManagement\Hotel.java
# 3    src\grupniProjekat_HotelManagement\MyConnector...
# 4          src\miniProjekat_05_02_2016\BattleShip.java
# ..                                                 ...
# 587  drools-spring-v2-app\src\main\java\drools\spri...
# 588       src\weka\core\stemmers\MilosevicStemmer.java
# 589       src\weka\core\stemmers\MilosevicStemmer.java
# 590       src\weka\core\stemmers\MilosevicStemmer.java
# 591         src\weka\core\stemmers\SerbianStemmer.java
#
#                                              CommentID  \
# 0    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 1    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 2    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 3    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 4    BILD-IT-Advanced-master/src\miniProjekat_05_02...
# ..                                                 ...
# 587  SBZ-master/drools-spring-v2-app\src\main\java\...
# 588  SCStemmers-master/src\weka\core\stemmers\Milos...
# 589  SCStemmers-master/src\weka\core\stemmers\Milos...
# 590  SCStemmers-master/src\weka\core\stemmers\Milos...
# 591  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                comment              label
# 0          klik na dugme guest na pocetku programa \n   Functional-Inline
# 1     prikaz slobodnih soba za izabrani tip priliko...  Functional-Inline
# 2     gost notifikuje adminu da zeli check out iz h...  Functional-Inline
# 3                             \n * Sefer Kuduzoviæ \n             General
# 4                     pravimo board velicine 5 * 5 \n   Functional-Inline
# ..                                                 ...                ...
# 587  racun.setOriginalnaUkupnaCena(racunDTO.getOrig...               Code
# 588   \n * Rečnik koji se koristi za normalizovanje...  Functional-Inline
# 589   Očuvava kapitalizaciju na početku rečenice \n...  Functional-Inline
# 590   \n * Ako se radi o karakteru koje spada u eng...  Functional-Inline
# 591   \n * Dužina (u karakterima) najdužeg sufiksno...  Functional-Inline
#
# [592 rows x 7 columns]

# %%
for i in range(merged.shape[0]):
    # dodeljuje se najverovatnija vrednost zajednickim komentarima
    if merged['comment'][i] in df.comment.values:
        arr = np.zeros(4) # niz u koji ce se upisati koliko se koji label pojavljuje
        for j in range(4):
            # za prvi label se prebroji koliko puta se pojavio i medju ostalim label-ima, i tako dalje za 2, 3, 4.
            arr[j] = merged.loc[i].str.count(merged.loc[i]['label_{}'.format(j+1)]).sum()
        # index u df-u gde je komentar jednak komentaru koji razmatramo u merged tabeli
        idx = df.loc[df['comment'] == merged['comment'][i]].index.values[0] 
        # za prethodno pronadjen red u data frame-u dodljuje se najcesci label
        df.loc[idx]['label'] = merged['label_{}'.format(arr.argmax()+1)][i]

# %%
df_common = pd.DataFrame(columns=df.columns)

# zadrzavaju se samo komentari iz df koji se nalaze i u merged 
for i in range(df.shape[0]):
    if df['comment'][i] in merged.comment.values:
        df_common = df_common.append(df.loc[i])

# %%
df_common = df_common.reset_index(drop=True)

# %%
df_common
# Out:
#     NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                  SR                    Java  BILD-IT-Advanced-master
# 1                  SR                    Java  BILD-IT-Advanced-master
# 2                  SR                    Java  BILD-IT-Advanced-master
# 3                  SR                    Java  BILD-IT-Advanced-master
# 4                  SR                    Java  BILD-IT-Advanced-master
# ..                ...                     ...                      ...
# 471                SR                    Java               SBZ-master
# 472                SR                    Java        SCStemmers-master
# 473                SR                    Java        SCStemmers-master
# 474                SR                    Java        SCStemmers-master
# 475                SR                    Java        SCStemmers-master
#
#                                               SourceID  \
# 0        src\grupniProjekat_HotelManagement\Hotel.java
# 1        src\grupniProjekat_HotelManagement\Hotel.java
# 2        src\grupniProjekat_HotelManagement\Hotel.java
# 3    src\grupniProjekat_HotelManagement\MyConnector...
# 4          src\miniProjekat_05_02_2016\BattleShip.java
# ..                                                 ...
# 471  drools-spring-v2-app\src\main\java\drools\spri...
# 472       src\weka\core\stemmers\MilosevicStemmer.java
# 473       src\weka\core\stemmers\MilosevicStemmer.java
# 474       src\weka\core\stemmers\MilosevicStemmer.java
# 475         src\weka\core\stemmers\SerbianStemmer.java
#
#                                              CommentID  \
# 0    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 1    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 2    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 3    BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 4    BILD-IT-Advanced-master/src\miniProjekat_05_02...
# ..                                                 ...
# 471  SBZ-master/drools-spring-v2-app\src\main\java\...
# 472  SCStemmers-master/src\weka\core\stemmers\Milos...
# 473  SCStemmers-master/src\weka\core\stemmers\Milos...
# 474  SCStemmers-master/src\weka\core\stemmers\Milos...
# 475  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                comment              label
# 0          klik na dugme guest na pocetku programa \n   Functional-Inline
# 1     prikaz slobodnih soba za izabrani tip priliko...  Functional-Inline
# 2     gost notifikuje adminu da zeli check out iz h...  Functional-Inline
# 3                             \n * Sefer Kuduzoviæ \n             General
# 4                     pravimo board velicine 5 * 5 \n   Functional-Inline
# ..                                                 ...                ...
# 471  racun.setOriginalnaUkupnaCena(racunDTO.getOrig...               Code
# 472   \n * Rečnik koji se koristi za normalizovanje...  Functional-Inline
# 473   Očuvava kapitalizaciju na početku rečenice \n...  Functional-Inline
# 474   \n * Ako se radi o karakteru koje spada u eng...  Functional-Inline
# 475   \n * Dužina (u karakterima) najdužeg sufiksno...  Functional-Inline
#
# [476 rows x 7 columns]

# %% [markdown]
# ## Ucitavanje svih podataka

# %%
def create_df():
    for id_ in range(1,5):
        try:
            cols = ['NaturalLanguageID', 'ProgrammingLanguageName', 'RepoID', 'SourceID', 'CommentID', 'comment', 'label']
            df = pd.read_csv('C:\\Users\\ASUS\\Desktop\\ETF\\V\\OPJ\\Data\\All data\\OutData{}.txt'.format(id_), sep='\t', lineterminator='\r', header=None)
            df.columns = cols
            #df = df.drop(['Programming language', 'project', 'source', 'line'],axis=1)
            if id_ == 1:
                dfs = df
            else:
                dfs = pd.concat([dfs,df], ignore_index=True)
        except:
            with open('C:\\Users\\ASUS\\Desktop\\ETF\\V\\OPJ\\Data\\All data\\OutData{}.txt'.format(id_), "r", encoding="utf-8",  newline="\r\n") as source:
                for line in source:
                    line = line.replace("\n", "")
                    part = line.split("\t")
                    if len(part) != 7:
                        print('POPRAVITI .TXT')
                        print(part)
    return dfs

# %%
df = create_df()

# %%
df = pd.concat([df, df_common], ignore_index=True)

# %%
df = df.dropna()

# %%
df
# Out:
#      NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                   SR                    Java  BILD-IT-Advanced-master
# 1                 \nSR                    Java  BILD-IT-Advanced-master
# 2                 \nSR                    Java  BILD-IT-Advanced-master
# 3                 \nSR                    Java  BILD-IT-Advanced-master
# 4                 \nSR                    Java  BILD-IT-Advanced-master
# ...                ...                     ...                      ...
# 6360                SR                    Java               SBZ-master
# 6361                SR                    Java        SCStemmers-master
# 6362                SR                    Java        SCStemmers-master
# 6363                SR                    Java        SCStemmers-master
# 6364                SR                    Java        SCStemmers-master
#
#                                                SourceID  \
# 0       src\grupniProjekat_02_03_2016\SearchEngine.java
# 1       src\grupniProjekat_02_03_2016\SearchEngine.java
# 2       src\grupniProjekat_02_03_2016\SearchEngine.java
# 3       src\grupniProjekat_02_03_2016\SearchEngine.java
# 4       src\grupniProjekat_02_03_2016\SearchEngine.java
# ...                                                 ...
# 6360  drools-spring-v2-app\src\main\java\drools\spri...
# 6361       src\weka\core\stemmers\MilosevicStemmer.java
# 6362       src\weka\core\stemmers\MilosevicStemmer.java
# 6363       src\weka\core\stemmers\MilosevicStemmer.java
# 6364         src\weka\core\stemmers\SerbianStemmer.java
#
#                                               CommentID  \
# 0     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 1     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 2     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 3     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 4     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# ...                                                 ...
# 6360  SBZ-master/drools-spring-v2-app\src\main\java\...
# 6361  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6362  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6363  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6364  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                 comment              label
# 0          Ispisujemo poruku da je drajver loadovan \n   Functional-Inline
# 1                 Ispis država za uneseni kontinent \n   Functional-Inline
# 2                                      Slanje upute \n   Functional-Inline
# 3       Ispis gradova koji pocinju odreðenim slovom \n   Functional-Inline
# 4                                 Hvatalica grešaka \n   Functional-Inline
# ...                                                 ...                ...
# 6360  racun.setOriginalnaUkupnaCena(racunDTO.getOrig...               Code
# 6361   \n * Rečnik koji se koristi za normalizovanje...  Functional-Inline
# 6362   Očuvava kapitalizaciju na početku rečenice \n...  Functional-Inline
# 6363   \n * Ako se radi o karakteru koje spada u eng...  Functional-Inline
# 6364   \n * Dužina (u karakterima) najdužeg sufiksno...  Functional-Inline
#
# [6365 rows x 7 columns]

# %%
for i in range(df.shape[0]):
    if df['NaturalLanguageID'][i][0] == '\n':
        df['NaturalLanguageID'][i] = df['NaturalLanguageID'][i][1:]

# %%
df.loc[df['NaturalLanguageID'] == 'UNDEF']
# Out:
#      NaturalLanguageID ProgrammingLanguageName  \
# 766              UNDEF                    Java
# 767              UNDEF                    Java
# 768              UNDEF                    Java
# 769              UNDEF                    Java
# 770              UNDEF                    Java
# ...                ...                     ...
# 5543             UNDEF                    Java
# 5544             UNDEF                    Java
# 5568             UNDEF                    Java
# 5794             UNDEF                    Java
# 6250             UNDEF                    Java
#
#                                RepoID  \
# 766   dusankrivosija-som-13d92a2b4d2a
# 767   dusankrivosija-som-13d92a2b4d2a
# 768   dusankrivosija-som-13d92a2b4d2a
# 769   dusankrivosija-som-13d92a2b4d2a
# 770   dusankrivosija-som-13d92a2b4d2a
# ...                               ...
# 5543                       OOP-master
# 5544                       OOP-master
# 5568                       OOP-master
# 5794                       OOP-master
# 6250                       OOP-master
#
#                                                SourceID  \
# 766                                DCT\src\dct\DCT.java
# 767                                DCT\src\dct\DCT.java
# 768                                DCT\src\dct\DCT.java
# 769                                DCT\src\dct\DCT.java
# 770                                DCT\src\dct\DCT.java
# ...                                                 ...
# 5543  predavanja\primeri-java\src\P040502Promenljive...
# 5544  predavanja\primeri-java\src\P040502Promenljive...
# 5568  predavanja\primeri-java\src\P060500Dvodimenzio...
# 5794  vezbe\primeri-java\09.kolekcije\src\dodatnoTok...
# 6250  predavanja\primeri-java\src\P040304OperatoriZ0...
#
#                                               CommentID  comment  \
# 766   dusankrivosija-som-13d92a2b4d2a/DCT\src\dct\DC...      2,0
# 767   dusankrivosija-som-13d92a2b4d2a/DCT\src\dct\DC...      1,2
# 768   dusankrivosija-som-13d92a2b4d2a/DCT\src\dct\DC...      3,1
# 769   dusankrivosija-som-13d92a2b4d2a/DCT\src\dct\DC...      0,5
# 770   dusankrivosija-som-13d92a2b4d2a/DCT\src\dct\DC...      4,1
# ...                                                 ...      ...
# 5543  OOP-master/predavanja\primeri-java\src\P040502...        5
# 5544  OOP-master/predavanja\primeri-java\src\P040502...       10
# 5568  OOP-master/predavanja\primeri-java\src\P060500...    15 30
# 5794  OOP-master/vezbe\primeri-java\09.kolekcije\src...        3
# 6250  OOP-master/predavanja\primeri-java\src\P040304...  9+(9*5)
#
#                   label
# 766   Functional-Method
# 767   Functional-Method
# 768   Functional-Method
# 769   Functional-Inline
# 770   Functional-Inline
# ...                 ...
# 5543  Functional-Inline
# 5544  Functional-Inline
# 5568  Functional-Inline
# 5794  Functional-Inline
# 6250  Functional-Inline
#
# [98 rows x 7 columns]

# %%
df = df.drop(df.loc[df['NaturalLanguageID'] == 'UNDEF'].index)

# %%
df
# Out:
#      NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                   SR                    Java  BILD-IT-Advanced-master
# 1                   SR                    Java  BILD-IT-Advanced-master
# 2                   SR                    Java  BILD-IT-Advanced-master
# 3                   SR                    Java  BILD-IT-Advanced-master
# 4                   SR                    Java  BILD-IT-Advanced-master
# ...                ...                     ...                      ...
# 6360                SR                    Java               SBZ-master
# 6361                SR                    Java        SCStemmers-master
# 6362                SR                    Java        SCStemmers-master
# 6363                SR                    Java        SCStemmers-master
# 6364                SR                    Java        SCStemmers-master
#
#                                                SourceID  \
# 0       src\grupniProjekat_02_03_2016\SearchEngine.java
# 1       src\grupniProjekat_02_03_2016\SearchEngine.java
# 2       src\grupniProjekat_02_03_2016\SearchEngine.java
# 3       src\grupniProjekat_02_03_2016\SearchEngine.java
# 4       src\grupniProjekat_02_03_2016\SearchEngine.java
# ...                                                 ...
# 6360  drools-spring-v2-app\src\main\java\drools\spri...
# 6361       src\weka\core\stemmers\MilosevicStemmer.java
# 6362       src\weka\core\stemmers\MilosevicStemmer.java
# 6363       src\weka\core\stemmers\MilosevicStemmer.java
# 6364         src\weka\core\stemmers\SerbianStemmer.java
#
#                                               CommentID  \
# 0     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 1     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 2     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 3     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 4     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# ...                                                 ...
# 6360  SBZ-master/drools-spring-v2-app\src\main\java\...
# 6361  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6362  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6363  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6364  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                 comment              label
# 0          Ispisujemo poruku da je drajver loadovan \n   Functional-Inline
# 1                 Ispis država za uneseni kontinent \n   Functional-Inline
# 2                                      Slanje upute \n   Functional-Inline
# 3       Ispis gradova koji pocinju odreðenim slovom \n   Functional-Inline
# 4                                 Hvatalica grešaka \n   Functional-Inline
# ...                                                 ...                ...
# 6360  racun.setOriginalnaUkupnaCena(racunDTO.getOrig...               Code
# 6361   \n * Rečnik koji se koristi za normalizovanje...  Functional-Inline
# 6362   Očuvava kapitalizaciju na početku rečenice \n...  Functional-Inline
# 6363   \n * Ako se radi o karakteru koje spada u eng...  Functional-Inline
# 6364   \n * Dužina (u karakterima) najdužeg sufiksno...  Functional-Inline
#
# [6267 rows x 7 columns]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#      NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                   SR                    Java  BILD-IT-Advanced-master
# 1                   SR                    Java  BILD-IT-Advanced-master
# 2                   SR                    Java  BILD-IT-Advanced-master
# 3                   SR                    Java  BILD-IT-Advanced-master
# 4                   SR                    Java  BILD-IT-Advanced-master
# ...                ...                     ...                      ...
# 6262                SR                    Java               SBZ-master
# 6263                SR                    Java        SCStemmers-master
# 6264                SR                    Java        SCStemmers-master
# 6265                SR                    Java        SCStemmers-master
# 6266                SR                    Java        SCStemmers-master
#
#                                                SourceID  \
# 0       src\grupniProjekat_02_03_2016\SearchEngine.java
# 1       src\grupniProjekat_02_03_2016\SearchEngine.java
# 2       src\grupniProjekat_02_03_2016\SearchEngine.java
# 3       src\grupniProjekat_02_03_2016\SearchEngine.java
# 4       src\grupniProjekat_02_03_2016\SearchEngine.java
# ...                                                 ...
# 6262  drools-spring-v2-app\src\main\java\drools\spri...
# 6263       src\weka\core\stemmers\MilosevicStemmer.java
# 6264       src\weka\core\stemmers\MilosevicStemmer.java
# 6265       src\weka\core\stemmers\MilosevicStemmer.java
# 6266         src\weka\core\stemmers\SerbianStemmer.java
#
#                                               CommentID  \
# 0     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 1     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 2     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 3     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 4     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# ...                                                 ...
# 6262  SBZ-master/drools-spring-v2-app\src\main\java\...
# 6263  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6264  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6265  SCStemmers-master/src\weka\core\stemmers\Milos...
# 6266  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                 comment              label
# 0          Ispisujemo poruku da je drajver loadovan \n   Functional-Inline
# 1                 Ispis država za uneseni kontinent \n   Functional-Inline
# 2                                      Slanje upute \n   Functional-Inline
# 3       Ispis gradova koji pocinju odreðenim slovom \n   Functional-Inline
# 4                                 Hvatalica grešaka \n   Functional-Inline
# ...                                                 ...                ...
# 6262  racun.setOriginalnaUkupnaCena(racunDTO.getOrig...               Code
# 6263   \n * Rečnik koji se koristi za normalizovanje...  Functional-Inline
# 6264   Očuvava kapitalizaciju na početku rečenice \n...  Functional-Inline
# 6265   \n * Ako se radi o karakteru koje spada u eng...  Functional-Inline
# 6266   \n * Dužina (u karakterima) najdužeg sufiksno...  Functional-Inline
#
# [6267 rows x 7 columns]

# %%
df.loc[df['NaturalLanguageID'] == 'EN/SR']
# Out:
#      NaturalLanguageID ProgrammingLanguageName  \
# 33               EN/SR                    Java
# 132              EN/SR                    Java
# 146              EN/SR                    Java
# 147              EN/SR                    Java
# 258              EN/SR                    Java
# ...                ...                     ...
# 6055             EN/SR                    Java
# 6059             EN/SR                    Java
# 6073             EN/SR                    Java
# 6076             EN/SR                    Java
# 6257             EN/SR                    Java
#
#                                           RepoID  \
# 33                       BILD-IT-Advanced-master
# 132                      BILD-IT-Advanced-master
# 146                      BILD-IT-Advanced-master
# 147                      BILD-IT-Advanced-master
# 258                   delboy-exgerm-b858e2a4b6f5
# ...                                          ...
# 6055  delboy-sportskakladionica-web-57e11bf14101
# 6059  delboy-sportskakladionica-web-57e11bf14101
# 6073  delboy-sportskakladionica-web-57e11bf14101
# 6076  delboy-sportskakladionica-web-57e11bf14101
# 6257                             raspored-master
#
#                                                SourceID  \
# 33            src\miniProjekat_14_01_2016\Kalendar.java
# 132                 src\zadaca_15_01_2016\Zadatak4.java
# 146                 src\zadaca_16_01_2016\Zadatak4.java
# 147                 src\zadaca_16_01_2016\Zadatak5.java
# 258     Core\tk\exgerm\core\actions\ActionRegister.java
# ...                                                 ...
# 6055                src\rs\in\delic\wp\Client\User.java
# 6059  src\rs\in\delic\wp\Client\Commands\ListFinishe...
# 6073  src\rs\in\delic\wp\Server\Commands\AddBetTicke...
# 6076  src\rs\in\delic\wp\Server\Commands\MatchResult...
# 6257    src\org\svetovid\raspored\io\Normalizatori.java
#
#                                               CommentID  \
# 33    BILD-IT-Advanced-master/src\miniProjekat_14_01...
# 132   BILD-IT-Advanced-master/src\zadaca_15_01_2016\...
# 146   BILD-IT-Advanced-master/src\zadaca_16_01_2016\...
# 147   BILD-IT-Advanced-master/src\zadaca_16_01_2016\...
# 258   delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# ...                                                 ...
# 6055  delboy-sportskakladionica-web-57e11bf14101/src...
# 6059  delboy-sportskakladionica-web-57e11bf14101/src...
# 6073  delboy-sportskakladionica-web-57e11bf14101/src...
# 6076  delboy-sportskakladionica-web-57e11bf14101/src...
# 6257  raspored-master/src\org\svetovid\raspored\io\N...
#
#                                                 comment              label
# 33                     \n * Author: Sefer Kuduzovic \n             General
# 132                    \n * Author: Sefer Kuduzovic \n             General
# 146                    \n * Author: Sefer Kuduzovic \n             General
# 147                    \n * Author: Sefer Kuduzovic \n             General
# 258    \n * Čuva sve instance akcija koje pravi Core...  Functional-Module
# ...                                                 ...                ...
# 6055   \n * @author del-boy \n * @version 0.01 \n * ...            General
# 6059                      \n * @author del-boy \n * \n             General
# 6073   \n * @author del-boy \n * \n * Klasa koja vrs...  Functional-Module
# 6076   \n * @author del-boy \n * \n * Radi komunikac...  Functional-Module
# 6257   \n * Ova klasa sluzi za cuvanje pravila norma...  Functional-Module
#
# [422 rows x 7 columns]

# %%
droped_duplicates = df.drop_duplicates(['comment'])

# %%
df.shape
# Out:
# (6267, 7)

# %%
droped_duplicates.shape
# Out:
# (4750, 7)

# %%
pd.set_option('display.max_rows', 10)

# %%
df.loc[df.duplicated('comment', keep=False)].sort_values('comment')
# Out:
#      NaturalLanguageID ProgrammingLanguageName                      RepoID  \
# 5738                SR                    Java             raspored-master
# 1369                SR                    Java             raspored-master
# 858                 SR                    Java   Language-processor-master
# 3927                SR                    Java   Language-processor-master
# 5293                SR                    Java   Language-processor-master
# ...                ...                     ...                         ...
# 1808                SR                    Java  delboy-exgerm-b858e2a4b6f5
# 4947                SR                    Java    delboy-germ-fab96483261f
# 3480                SR                    Java    delboy-germ-fab96483261f
# 4948                SR                    Java    delboy-germ-fab96483261f
# 4949                SR                    Java    delboy-germ-fab96483261f
#
#                                                SourceID  \
# 5738            src\org\svetovid\raspored\cmd\Main.java
# 1369            src\org\svetovid\raspored\cmd\Main.java
# 858   Language-processor\src\hr\unizg\fer\lab3\Izraz...
# 3927  Language-processor\src\hr\unizg\fer\labComplet...
# 5293  Language-processor\src\hr\unizg\fer\lab4\Izraz...
# ...                                                 ...
# 1808  GraphTree\tk\exgerm\graphtree\listeners\NodeRe...
# 4947              germ\gui\workspace\WorkspaceTree.java
# 3480              germ\gui\workspace\WorkspaceTree.java
# 4948              germ\gui\workspace\WorkspaceTree.java
# 4949              germ\gui\workspace\WorkspaceTree.java
#
#                                               CommentID  \
# 5738  raspored-master/src\org\svetovid\raspored\cmd\...
# 1369  raspored-master/src\org\svetovid\raspored\cmd\...
# 858   Language-processor-master/Language-processor\s...
# 3927  Language-processor-master/Language-processor\s...
# 5293  Language-processor-master/Language-processor\s...
# ...                                                 ...
# 1808  delboy-exgerm-b858e2a4b6f5/GraphTree\tk\exgerm...
# 4947  delboy-germ-fab96483261f/germ\gui\workspace\Wo...
# 3480  delboy-germ-fab96483261f/germ\gui\workspace\Wo...
# 4948  delboy-germ-fab96483261f/germ\gui\workspace\Wo...
# 4949  delboy-germ-fab96483261f/germ\gui\workspace\Wo...
#
#                                                 comment              label
# 5738                    "nikad" "po-potrebi" "uvek" \n   Functional-Inline
# 1369                    "nikad" "po-potrebi" "uvek" \n   Functional-Inline
# 858                                         ++ i -- \n   Functional-Inline
# 3927                                        ++ i -- \n                Code
# 5293                                        ++ i -- \n   Functional-Inline
# ...                                                 ...                ...
# 1808  uzimamo root graf i u zavisnosti od broja nivo...  Functional-Inline
# 4947                            uzimanje popup menu \n   Functional-Inline
# 3480                            uzimanje popup menu \n   Functional-Inline
# 4948                            uzimanje popup menu \n   Functional-Inline
# 4949                            uzimanje popup menu \n   Functional-Inline
#
# [2069 rows x 7 columns]

# %%
droped_duplicates[droped_duplicates.index == 3676]
# Out:
#      NaturalLanguageID ProgrammingLanguageName  \
# 3676                SR                    Java
#
#                                RepoID  \
# 3676  dusankrivosija-som-13d92a2b4d2a
#
#                                          SourceID  \
# 3676  Neuroph\org\neuroph\contrib\IACNetwork.java
#
#                                               CommentID   comment  \
# 3676  dusankrivosija-som-13d92a2b4d2a/Neuroph\org\ne...   Burglar
#
#                   label
# 3676  Functional-Inline

# %%
df = df.drop_duplicates(['comment'])
df = df.reset_index(drop=True)

# %%
df = df.drop(df[df['comment'].str.contains('NON')].index)

# %%
df['label'].value_counts()
# Out:
# Functional-Inline    2800
# Functional-Method    1075
# Functional-Module     500
# Notice                146
# Code                  110
# General                66
# ToDo                   31
# IDE                    20
# Name: label, dtype: int64

# %%
df[df['label'] == 'Notice']
# Out:
#      NaturalLanguageID ProgrammingLanguageName                      RepoID  \
# 219                 SR                    Java     BILD-IT-Advanced-master
# 332                 SR                    Java  delboy-exgerm-b858e2a4b6f5
# 985                 SR                    Java                  OOP-master
# 1032                SR                    Java                  OOP-master
# 1044                SR                    Java                  OOP-master
# ...                ...                     ...                         ...
# 4306                SR                    Java                  OOP-master
# 4313                SR                    Java                  OOP-master
# 4317                SR                    Java                  OOP-master
# 4375                SR                    Java           SCStemmers-master
# 4724                SR                    Java                  OOP-master
#
#                                                SourceID  \
# 219                 src\zadaca_30_01_2016\Zadatak3.java
# 332   Core\tk\exgerm\core\register\GraphRegisterProx...
# 985   predavanja\primeri-java\src\rs\math\oop1\z0705...
# 1032  predavanja\primeri-java\src\rs\math\oop1\z1001...
# 1044  predavanja\primeri-java\src\rs\math\oop1\z1903...
# ...                                                 ...
# 4306  vezbe\primeri-java\08.genericke.klase\src\prim...
# 4313  vezbe\primeri-java\09.kolekcije\src\primer03Se...
# 4317  vezbe\primeri-java\10.poredjenje.objekata\src\...
# 4375       src\weka\core\stemmers\MilosevicStemmer.java
# 4724  vezbe\primeri-java\09.kolekcije\src\primer01Li...
#
#                                               CommentID  \
# 219   BILD-IT-Advanced-master/src\zadaca_30_01_2016\...
# 332   delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# 985   OOP-master/predavanja\primeri-java\src\rs\math...
# 1032  OOP-master/predavanja\primeri-java\src\rs\math...
# 1044  OOP-master/predavanja\primeri-java\src\rs\math...
# ...                                                 ...
# 4306  OOP-master/vezbe\primeri-java\08.genericke.kla...
# 4313  OOP-master/vezbe\primeri-java\09.kolekcije\src...
# 4317  OOP-master/vezbe\primeri-java\10.poredjenje.ob...
# 4375  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4724  OOP-master/vezbe\primeri-java\09.kolekcije\src...
#
#                                                 comment   label
# 219    \n * http://stackoverflow.com/questions/40874...  Notice
# 332    pošto smo prvo proverili da li graf postoji, ...  Notice
# 985                 ovo nikad ne treba da bude izvrseno  Notice
# 1032                         OVAKO NE TREBA RADITI! \n   Notice
# 1044   Metod Integer.parseInt() moze dovesti do izba...  Notice
# ...                                                 ...     ...
# 4306   Cesto je korisno imati staticke funkcije koje...  Notice
# 4313   ---------------------------------------------...  Notice
# 4317   \n Sortiranje mozemo izvrsiti i nad nasim kla...  Notice
# 4375   Ovi oblici se ne javljaju u ArXiv radu. Oni s...  Notice
# 4724   Lista se moze ispisati na standardni izlaz i ...  Notice
#
# [146 rows x 7 columns]

# %%
df[df['label'] == 'General']
# Out:
#      NaturalLanguageID ProgrammingLanguageName  \
# 32               EN/SR                    Java
# 254              EN/SR                    Java
# 641                 SR                    Java
# 642                 SR                    Java
# 644                 SR                    Java
# ...                ...                     ...
# 4219                SR                    Java
# 4232             EN/SR                    Java
# 4272                SR                    Java
# 4383                SR                    Java
# 4611             EN/SR                    Java
#
#                                            RepoID  \
# 32                        BILD-IT-Advanced-master
# 254                    delboy-exgerm-b858e2a4b6f5
# 641   delboy-sportskakladionica-mbs2-9fe0a4caa6be
# 642   delboy-sportskakladionica-mbs2-9fe0a4caa6be
# 644   delboy-sportskakladionica-mbs2-9fe0a4caa6be
# ...                                           ...
# 4219                                   OOP-master
# 4232                                   OOP-master
# 4272                                   OOP-master
# 4383                      BILD-IT-Advanced-master
# 4611   delboy-sportskakladionica-web-57e11bf14101
#
#                                                SourceID  \
# 32            src\miniProjekat_14_01_2016\Kalendar.java
# 254   Core\tk\exgerm\core\exception\ExGEdgeDoesNotEx...
# 641   SportBetting\src\rs\in\delic\mbs2\SportBetting...
# 642   SportBetting\src\rs\in\delic\mbs2\SportBetting...
# 644   SportBetting\src\rs\in\delic\mbs2\SportBetting...
# ...                                                 ...
# 4219  predavanja\primeri-java\src\rs\math\oop1\z0804...
# 4232  predavanja\primeri-java\src\rs\math\oop1\z1701...
# 4272  vezbe\primeri-java\02.nizovi.matrice.stringovi...
# 4383  src\grupniProjekat_HotelManagement\MyConnector...
# 4611             src\rs\in\delic\wp\ServerResponse.java
#
#                                               CommentID  \
# 32    BILD-IT-Advanced-master/src\miniProjekat_14_01...
# 254   delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# 641   delboy-sportskakladionica-mbs2-9fe0a4caa6be/Sp...
# 642   delboy-sportskakladionica-mbs2-9fe0a4caa6be/Sp...
# 644   delboy-sportskakladionica-mbs2-9fe0a4caa6be/Sp...
# ...                                                 ...
# 4219  OOP-master/predavanja\primeri-java\src\rs\math...
# 4232  OOP-master/predavanja\primeri-java\src\rs\math...
# 4272  OOP-master/vezbe\primeri-java\02.nizovi.matric...
# 4383  BILD-IT-Advanced-master/src\grupniProjekat_Hot...
# 4611  delboy-sportskakladionica-web-57e11bf14101/src...
#
#                                                 comment    label
# 32                     \n * Author: Sefer Kuduzovic \n   General
# 254                         \n * @author Tim 2 \n * \n   General
# 641    \n * Bojan Delić, e11510 \n * Projekat iz pre...  General
# 642    \n * Bojan Delić, e11510 \n * Projekat iz pre...  General
# 644    \n * Bojan Delić, e11510 \n * Projekat iz pre...  General
# ...                                                 ...      ...
# 4219   \n * \n * Program ilustruje koncept polimorfi...  General
# 4232   \n * @version 1.10 17 Aug 1998 \n * @author C...  General
# 4272  / Program ilistruje kako mozemo sortirati Stri...  General
# 4383                           \n * Sefer Kuduzoviæ \n   General
# 4611   \n * @author del-boy \n * \n * Sve stvari koj...  General
#
# [66 rows x 7 columns]

# %%
df.loc[df.index == 2044]['comment'][2044]
# Out:
# ' Prvi nacin, jedna linija :) \\n  igre.sort(Comparator.comparing(VideoIgra::getIme)); \\n '

# %%
df = df.drop(df[df.comment.apply(lambda x: len(str(x)) < 6)].index)

# %%
df
# Out:
#      NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                   SR                    Java  BILD-IT-Advanced-master
# 1                   SR                    Java  BILD-IT-Advanced-master
# 2                   SR                    Java  BILD-IT-Advanced-master
# 3                   SR                    Java  BILD-IT-Advanced-master
# 4                   SR                    Java  BILD-IT-Advanced-master
# ...                ...                     ...                      ...
# 4745                SR                    Java              RAUM-master
# 4746                SR                    Java               SBZ-master
# 4747                SR                    Java        SCStemmers-master
# 4748                SR                    Java        SCStemmers-master
# 4749                SR                    Java        SCStemmers-master
#
#                                                SourceID  \
# 0       src\grupniProjekat_02_03_2016\SearchEngine.java
# 1       src\grupniProjekat_02_03_2016\SearchEngine.java
# 2       src\grupniProjekat_02_03_2016\SearchEngine.java
# 3       src\grupniProjekat_02_03_2016\SearchEngine.java
# 4       src\grupniProjekat_02_03_2016\SearchEngine.java
# ...                                                 ...
# 4745                                      funkcija.java
# 4746  drools-spring-v2-app\src\main\java\drools\spri...
# 4747       src\weka\core\stemmers\MilosevicStemmer.java
# 4748       src\weka\core\stemmers\MilosevicStemmer.java
# 4749         src\weka\core\stemmers\SerbianStemmer.java
#
#                                               CommentID  \
# 0     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 1     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 2     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 3     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 4     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# ...                                                 ...
# 4745                      RAUM-master/funkcija.java/294
# 4746  SBZ-master/drools-spring-v2-app\src\main\java\...
# 4747  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4748  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4749  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                 comment              label
# 0          Ispisujemo poruku da je drajver loadovan \n   Functional-Inline
# 1                 Ispis država za uneseni kontinent \n   Functional-Inline
# 2                                      Slanje upute \n   Functional-Inline
# 3       Ispis gradova koji pocinju odreðenim slovom \n   Functional-Inline
# 4                                 Hvatalica grešaka \n   Functional-Inline
# ...                                                 ...                ...
# 4745           sad je podfunkcija oblika funkcija(broj)  Functional-Inline
# 4746  racun.setOriginalnaUkupnaCena(racunDTO.getOrig...               Code
# 4747   \n * Rečnik koji se koristi za normalizovanje...  Functional-Inline
# 4748   Očuvava kapitalizaciju na početku rečenice \n...  Functional-Inline
# 4749   \n * Dužina (u karakterima) najdužeg sufiksno...  Functional-Inline
#
# [4710 rows x 7 columns]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#      NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                   SR                    Java  BILD-IT-Advanced-master
# 1                   SR                    Java  BILD-IT-Advanced-master
# 2                   SR                    Java  BILD-IT-Advanced-master
# 3                   SR                    Java  BILD-IT-Advanced-master
# 4                   SR                    Java  BILD-IT-Advanced-master
# ...                ...                     ...                      ...
# 4705                SR                    Java              RAUM-master
# 4706                SR                    Java               SBZ-master
# 4707                SR                    Java        SCStemmers-master
# 4708                SR                    Java        SCStemmers-master
# 4709                SR                    Java        SCStemmers-master
#
#                                                SourceID  \
# 0       src\grupniProjekat_02_03_2016\SearchEngine.java
# 1       src\grupniProjekat_02_03_2016\SearchEngine.java
# 2       src\grupniProjekat_02_03_2016\SearchEngine.java
# 3       src\grupniProjekat_02_03_2016\SearchEngine.java
# 4       src\grupniProjekat_02_03_2016\SearchEngine.java
# ...                                                 ...
# 4705                                      funkcija.java
# 4706  drools-spring-v2-app\src\main\java\drools\spri...
# 4707       src\weka\core\stemmers\MilosevicStemmer.java
# 4708       src\weka\core\stemmers\MilosevicStemmer.java
# 4709         src\weka\core\stemmers\SerbianStemmer.java
#
#                                               CommentID  \
# 0     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 1     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 2     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 3     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 4     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# ...                                                 ...
# 4705                      RAUM-master/funkcija.java/294
# 4706  SBZ-master/drools-spring-v2-app\src\main\java\...
# 4707  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4708  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4709  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                 comment              label
# 0          Ispisujemo poruku da je drajver loadovan \n   Functional-Inline
# 1                 Ispis država za uneseni kontinent \n   Functional-Inline
# 2                                      Slanje upute \n   Functional-Inline
# 3       Ispis gradova koji pocinju odreðenim slovom \n   Functional-Inline
# 4                                 Hvatalica grešaka \n   Functional-Inline
# ...                                                 ...                ...
# 4705           sad je podfunkcija oblika funkcija(broj)  Functional-Inline
# 4706  racun.setOriginalnaUkupnaCena(racunDTO.getOrig...               Code
# 4707   \n * Rečnik koji se koristi za normalizovanje...  Functional-Inline
# 4708   Očuvava kapitalizaciju na početku rečenice \n...  Functional-Inline
# 4709   \n * Dužina (u karakterima) najdužeg sufiksno...  Functional-Inline
#
# [4710 rows x 7 columns]

# %% [markdown]
# Preprocessing all comments

# %%
for i in range(df.shape[0]):
    # pretvaranje celog teksta u mala slova
    df.loc[i]['comment'] = df.loc[i]['comment'].lower()
    # izbacivanje special character-a
    df['comment'][i] = re.sub(r'\W', ' ', df['comment'][i])
    # izbacivanje new line oznake
    df['comment'][i] = re.sub(r'\b[n]\b', '', df['comment'][i])
    # zamena vise razmaka s jednim razmakom
    df['comment'][i] = re.sub(r'\s+', ' ', df['comment'][i], flags=re.I)

# %%
for i in range(30):
    print(df['comment'][i])
# Out:
#  ispisujemo poruku da je drajver loadovan
#  ispis država za uneseni kontinent
#  slanje upute
#  ispis gradova koji pocinju odreðenim slovom
#  hvatalica grešaka
#  konstruktor sa data fields
#  guest button
#  ok button za login admin
#  zatvaranje pregleda racuna
#  button za pregled racuna za datog korisnika
#  button za spasavanje update a gosta
#  panel sa boxom i poljem za unos nove sobe na zahtjev gosta
#  button za prikaz slobodnih soba datog tipa
#  tabs admin halim
#  polja za unos podataka o gostu
#  sljedeæe linije su za panel 1 i panel 2 admin window za ostale usluge hotela
#  prilikom logina ako zelimo da odustanemo i vratimo se na poèetak
#  prikaz notifikacija adminu ukoliko neki gost zeli check out
#  ucitavanje podataka o sobi i gostu za kreiranje racuna za prikaz
#  prijava novog gosta u hotel
#  brisanje notifikacije za check out
#  editovanje podataka o gostu tab2 admin windows guest lookup and change podataka
#  gost sacuva podatke koje je mjenjao direktno u bazu
#  sql driver
#  notifikacija by halim
#  brojace za broj pokušaja i broj pogodaka
#  metoda za ispis table
#  provjeravamo da li smo slucajno 2 puta stavili brod na isto mjesto
#  metoda koja updatea tablu
#  pozivamo metode za rijec

# %%
df
# Out:
#      NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                   SR                    Java  BILD-IT-Advanced-master
# 1                   SR                    Java  BILD-IT-Advanced-master
# 2                   SR                    Java  BILD-IT-Advanced-master
# 3                   SR                    Java  BILD-IT-Advanced-master
# 4                   SR                    Java  BILD-IT-Advanced-master
# ...                ...                     ...                      ...
# 4705                SR                    Java              RAUM-master
# 4706                SR                    Java               SBZ-master
# 4707                SR                    Java        SCStemmers-master
# 4708                SR                    Java        SCStemmers-master
# 4709                SR                    Java        SCStemmers-master
#
#                                                SourceID  \
# 0       src\grupniProjekat_02_03_2016\SearchEngine.java
# 1       src\grupniProjekat_02_03_2016\SearchEngine.java
# 2       src\grupniProjekat_02_03_2016\SearchEngine.java
# 3       src\grupniProjekat_02_03_2016\SearchEngine.java
# 4       src\grupniProjekat_02_03_2016\SearchEngine.java
# ...                                                 ...
# 4705                                      funkcija.java
# 4706  drools-spring-v2-app\src\main\java\drools\spri...
# 4707       src\weka\core\stemmers\MilosevicStemmer.java
# 4708       src\weka\core\stemmers\MilosevicStemmer.java
# 4709         src\weka\core\stemmers\SerbianStemmer.java
#
#                                               CommentID  \
# 0     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 1     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 2     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 3     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 4     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# ...                                                 ...
# 4705                      RAUM-master/funkcija.java/294
# 4706  SBZ-master/drools-spring-v2-app\src\main\java\...
# 4707  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4708  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4709  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                 comment              label
# 0             ispisujemo poruku da je drajver loadovan   Functional-Inline
# 1                    ispis država za uneseni kontinent   Functional-Inline
# 2                                         slanje upute   Functional-Inline
# 3          ispis gradova koji pocinju odreðenim slovom   Functional-Inline
# 4                                    hvatalica grešaka   Functional-Inline
# ...                                                 ...                ...
# 4705           sad je podfunkcija oblika funkcija broj   Functional-Inline
# 4706  racun setoriginalnaukupnacena racundto getorig...               Code
# 4707   rečnik koji se koristi za normalizovanje čest...  Functional-Inline
# 4708   očuvava kapitalizaciju na početku rečenice pr...  Functional-Inline
# 4709   dužina u karakterima najdužeg sufiksnog pravi...  Functional-Inline
#
# [4710 rows x 7 columns]

# %% [markdown]
# ## ML

# %%
df['comment'].values
# Out:
# array([' ispisujemo poruku da je drajver loadovan ',
#        ' ispis država za uneseni kontinent ', ' slanje upute ', ...,
#        ' rečnik koji se koristi za normalizovanje često korišćenih nepravilnih glagola p i a dictionary which is used to normalize the frequently used irregular verbs i ',
#        ' očuvava kapitalizaciju na početku rečenice preserves the capitalization at the start of a sentence ',
#        ' dužina u karakterima najdužeg sufiksnog pravila p i length in characters of the longest suffix rule i '],
#       dtype=object)

# %%
df.label.value_counts()
# Out:
# Functional-Inline    2767
# Functional-Method    1075
# Functional-Module     500
# Notice                142
# Code                  110
# General                66
# ToDo                   30
# IDE                    20
# Name: label, dtype: int64

# %%
inline_rnd = df[df.label == 'Functional-Inline'].sample(500)

# %%
method_rnd = df[df.label == 'Functional-Method'].sample(500)

# %%
df_proba = pd.concat([df[df.label == 'Functional-Module'], df[df.label == 'Functional-Module'],
                     df[df.label == 'Notice'], df[df.label == 'Code'],
                     df[df.label == 'General'], df[df.label == 'ToDo'],
                     df[df.label == 'IDE'], inline_rnd, method_rnd], ignore_index=True)

# %%
df_proba
# Out:
#      NaturalLanguageID ProgrammingLanguageName                      RepoID  \
# 0                EN/SR                    Java  delboy-exgerm-b858e2a4b6f5
# 1                EN/SR                    Java  delboy-exgerm-b858e2a4b6f5
# 2                EN/SR                    Java  delboy-exgerm-b858e2a4b6f5
# 3                EN/SR                    Java  delboy-exgerm-b858e2a4b6f5
# 4                EN/SR                    Java  delboy-exgerm-b858e2a4b6f5
# ...                ...                     ...                         ...
# 2362                SR                    Java    delboy-germ-fab96483261f
# 2363                SR                    Java    delboy-germ-fab96483261f
# 2364             EN/SR                    Java  delboy-exgerm-b858e2a4b6f5
# 2365                SR                    Java  delboy-exgerm-b858e2a4b6f5
# 2366                SR                    Java                  OOP-master
#
#                                                SourceID  \
# 0       Core\tk\exgerm\core\actions\ActionRegister.java
# 1                Core\tk\exgerm\core\gui\StatusBar.java
# 2     Core\tk\exgerm\core\gui\tabmanager\TabManager....
# 3     Core\tk\exgerm\core\gui\tabmanager\listeners\T...
# 4     Core\tk\exgerm\core\gui\tabmanager\listeners\T...
# ...                                                 ...
# 2362                germ\actions\AlignBottomAction.java
# 2363               germ\gui\windows\SettingsWindow.java
# 2364   Core\tk\exgerm\core\gui\tabmanager\TabPanel.java
# 2365               Help\tk\exgerm\help\HelpService.java
# 2366  kolokvijumi\resenja\kol201516_Dosije\src\dosij...
#
#                                               CommentID  \
# 0     delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# 1     delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# 2     delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# 3     delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# 4     delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# ...                                                 ...
# 2362  delboy-germ-fab96483261f/germ\actions\AlignBot...
# 2363  delboy-germ-fab96483261f/germ\gui\windows\Sett...
# 2364  delboy-exgerm-b858e2a4b6f5/Core\tk\exgerm\core...
# 2365  delboy-exgerm-b858e2a4b6f5/Help\tk\exgerm\help...
# 2366  OOP-master/kolokvijumi\resenja\kol201516_Dosij...
#
#                                                 comment              label
# 0      čuva sve instance akcija koje pravi core i ne...  Functional-Module
# 1      klasa za prikaz statusnih poruka pomoćnih dug...  Functional-Module
# 2      klasa implementira funkcionalnost radnog pros...  Functional-Module
# 3      klasa koja reaguje na klik i prelazak miša pr...  Functional-Module
# 4      reaguje na događaje miša na tabbed pane u aut...  Functional-Module
# ...                                                 ...                ...
# 2362   metoda promeni polozaj svim node elementima t...  Functional-Method
# 2363   funkcija popunjava lanuage combobox sa adekva...  Functional-Method
# 2364   predstavlja panel koji sadrži link exggraphic...  Functional-Method
# 2365   metoda inicijalizuje sve listenere potrebne z...  Functional-Method
# 2366                                       konstruktor   Functional-Method
#
# [2367 rows x 7 columns]

# %%
df['label'].values
# Out:
# array(['Functional-Inline', 'Functional-Inline', 'Functional-Inline', ...,
#        'Functional-Inline', 'Functional-Inline', 'Functional-Inline'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df['comment'].values, df['label'].values, test_size=0.2, random_state=1000)

# %%
type(x_test)
# Out:
# numpy.ndarray

# %%
# Pokrenuti ovo za koriscenje stemmovanja

import nltk
nltk.download('punkt')

import StemmerByNikola
from StemmerByNikola import stem_str
    
stemmed_x_train = []
for doc in x_train:
    stemmed_x_train.append(stem_str(doc))
    
stemmed_x_test = []
for doc in x_test:
    stemmed_x_test.append(stem_str(doc))
    
x_train = np.array(stemmed_x_train)
x_test = np.array(stemmed_x_test)
    
# print(stemmed_x_train)
# print(type(stemmed_x_train))
# print(type(np.array(stemmed_x_train)))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
x_train
# Out:
# array([' oznacava trenut cvor kao posecen', ' print karakter', ' nij ok',
#        ..., ' postavlja sist u pocet stanj', ' generis nasumic boj',
#        ' ni na kra'], dtype='<U2405')

# %%
# Deo gde se radi obicna vektorizacija bez TF-IDF
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer='word', 
#                              lowercase=True, # Menjanjem ovoga testiramo lowercase uticaj
                             ngram_range=(1, 2), # Podesavanjem ovoga testiramo bigramski i trigramski uticaj
                             min_df=1, max_df=1.0) # Podesavanjem ova dva testiracemo uticaj frekvencijskog filtriranja

# vectorizer = CountVectorizer()

vectorizer.fit(x_train)

x_train = vectorizer.transform(x_train)
x_test  = vectorizer.transform(x_test)
x_train
# Out:
# <3768x8369 sparse matrix of type '<class 'numpy.int64'>'
# 	with 37347 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidfconverter = TfidfTransformer()
X_train = tfidfconverter.fit_transform(x_train).toarray()
X_test = tfidfconverter.fit_transform(x_test).toarray()

# %% [markdown]
# ## Logistic regression L1 penalty

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

classifier = LogisticRegression(penalty='l1')
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

print("Accuracy:", classifier.score(X_test, y_test))
print("F1 score:", f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy: 0.79723991507431
# F1 score: 0.5297236938923501

# %% [markdown]
# ## Logistic regression L2 penalty

# %%
from sklearn.metrics import classification_report

classifier = LogisticRegression(penalty='l2')
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

print("Accuracy:", classifier.score(X_test, y_test))
print("F1 score:", f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy: 0.8014861995753716
# F1 score: 0.41258078827174655
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Grid search for finding the optimal C value

# %%
from sklearn.model_selection import GridSearchCV

#parameters = {'C':[0.1, 0.5, 1, 1.5, 2, 5]}
parameters = {'C':[0.5, 1, 2, 5, 7, 10]}
log_reg = LogisticRegression(penalty='l2')
clf = GridSearchCV(log_reg, parameters, scoring='f1_macro')
clf.fit(X_train, y_train)
#sorted(clf.cv_results_.keys())
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='warn',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='warn',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='warn', n_jobs=None, param_grid={'C': [0.5, 1, 2, 5, 7, 10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_macro', verbose=0)

# %%
clf.best_params_
# Out:
# {'C': 10}

# %%
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print("Accuracy:", clf.score(X_test, y_test))
print("F1 score:", f1_score(y_test, y_pred, average='weighted'))
# Out:
#                    precision    recall  f1-score   support
#
#              Code       0.79      0.44      0.56        25
# Functional-Inline       0.84      0.93      0.88       568
# Functional-Method       0.83      0.79      0.81       222
# Functional-Module       0.82      0.72      0.77        82
#           General       0.50      0.25      0.33         8
#               IDE       1.00      0.50      0.67         2
#            Notice       0.18      0.07      0.10        29
#              ToDo       1.00      0.50      0.67         6
#
#          accuracy                           0.83       942
#         macro avg       0.74      0.52      0.60       942
#      weighted avg       0.81      0.83      0.82       942
#
# Accuracy: 0.5985935918590396
# F1 score: 0.8160973490956525

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred, labels = df['label'].unique())
# Out:
# array([[526,  30,   0,   3,   7,   0,   0,   2],
#        [ 45, 176,   1,   0,   0,   0,   0,   0],
#        [  0,   1,   2,   1,   4,   0,   0,   0],
#        [ 24,   0,   0,   2,   2,   0,   0,   1],
#        [ 14,   5,   1,   3,  59,   0,   0,   0],
#        [  0,   1,   0,   0,   0,   1,   0,   0],
#        [  2,   0,   0,   1,   0,   0,   3,   0],
#        [ 13,   0,   0,   1,   0,   0,   0,  11]], dtype=int64)

# %%
from matplotlib import pyplot as plt
import seaborn as sn
# %matplotlib inline

def plot_confusion_matrix(y_test, y_pred):
    data = confusion_matrix(y_test, y_pred)
    df_cm = pd.DataFrame(data, columns=np.unique(y_test), index = np.unique(y_test))
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (10,7))
    sn.set(font_scale=1.4)#for label size
    sn.heatmap(df_cm, cmap="Blues", annot=True, fmt="d", annot_kws={"size": 16})# font size

# %%
plot_confusion_matrix(y_test, y_pred)

# %% [markdown]
# ## Multinomial Naive Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy:", clf.score(X_test, y_test))
print("F1 score:", f1_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy: 0.7229299363057324
# F1 score: 0.6706726581071338
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
plot_confusion_matrix(y_test, y_pred)

# %% [markdown]
# ## Bernoulli Naive Bayes Classifier

# %%
from sklearn.naive_bayes import BernoulliNB

clf = BernoulliNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy:", clf.score(X_test, y_test))
print("F1 score:", f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy: 0.7346072186836518
# F1 score: 0.2461806923214904
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
plot_confusion_matrix(y_test, y_pred)

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC(penalty='l2')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy:", clf.score(X_test, y_test))
print("F1 score:", f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy: 0.8386411889596603
# F1 score: 0.6293879449021391

# %%
parameters = {'C':[0.5, 1, 2, 5, 7, 10]}
log_reg = LogisticRegression(penalty='l2')
clf = GridSearchCV(log_reg, parameters, scoring='f1_macro')
clf.fit(X_train, y_train)

print('Best C value:', clf.best_params_)

y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print("Accuracy:", clf.score(X_test, y_test))
print("F1 score:", f1_score(y_test, y_pred, average='weighted'))
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ASUS\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best C value: {'C': 10}
#                    precision    recall  f1-score   support
#
#              Code       0.79      0.44      0.56        25
# Functional-Inline       0.84      0.94      0.89       568
# Functional-Method       0.86      0.77      0.81       222
# Functional-Module       0.81      0.77      0.79        82
#           General       0.50      0.25      0.33         8
#               IDE       1.00      0.50      0.67         2
#            Notice       0.22      0.07      0.11        29
#              ToDo       1.00      0.50      0.67         6
#
#          accuracy                           0.84       942
#         macro avg       0.75      0.53      0.60       942
#      weighted avg       0.82      0.84      0.82       942
#
# Accuracy: 0.6031692105530401
# F1 score: 0.823355592911926

# %%
plot_confusion_matrix(y_true, y_pred)

# %%
vectorizer.vocabulary_
# Out:
# {'oznacavamo': 4284,
#  'trenutni': 6833,
#  'cvor': 874,
#  'kao': 2542,
#  'posecen': 4704,
#  'print': 5162,
#  'karaktera': 2548,
#  'nije': 3706,
#  'ok': 4044,
#  'korisnik': 2868,
#  'unosi': 7003,
#  'broj': 522,
#  'koji': 2666,
#  'æe': 7634,
#  'generirati': 1653,
#  'matricu': 3212,
#  'dvodimenzionalna': 1334,
#  'matrica': 3209,
#  'програм': 8158,
#  'илуструје': 7840,
#  'валидно': 7731,
#  'препоручено': 8131,
#  'именовање': 7844,
#  'идентификатора': 7815,
#  'javlja': 2444,
#  'state': 6302,
#  'mašini': 3222,
#  'da': 883,
#  'se': 5865,
#  'desio': 1012,
#  'događaj': 1211,
#  'povlačenja': 4811,
#  'miša': 3325,
#  'updateuje': 7023,
#  'link': 3043,
#  'germview': 1673,
#  'hanlemoving': 1849,
#  'lastposition': 2987,
#  'ako': 181,
#  'je': 2451,
#  'selektovan': 5890,
#  'tacno': 6568,
#  'jedan': 2452,
#  'node': 3772,
#  'arrayalg': 303,
#  'pair': 4300,
#  'zaposleni': 7529,
#  'minmax': 3314,
#  'ljudi': 3080,
#  'inicijalizacija': 2083,
#  'za': 7440,
#  'treepopdiagram': 6823,
#  'metoda': 3283,
#  'koju': 2672,
#  'implementiraju': 2023,
#  'samo': 5816,
#  'neki': 3624,
#  'iteratori': 2273,
#  'kako': 2530,
#  'bi': 425,
#  'omogućili': 4077,
#  'čišćenje': 7671,
#  'podataka': 4464,
#  'koje': 2663,
#  'su': 6436,
#  'stavili': 6327,
#  'graf': 1773,
#  'svaki': 6491,
#  'iterator': 2270,
#  'opisu': 4141,
#  'klase': 2592,
#  'definiše': 953,
#  'li': 3024,
#  'posle': 4713,
#  'njega': 3741,
#  'potrebno': 4783,
#  'pozivati': 4843,
#  'ovu': 4282,
#  'metodu': 3289,
#  'password': 4365,
#  'field': 1537,
#  'todo': 6716,
#  'dodati': 1183,
#  'čuvanje': 7675,
#  'ostalih': 4208,
#  'standardnih': 6282,
#  'opcija': 4111,
#  'toku': 6728,
#  'razvoj': 5545,
#  'jeste': 2493,
#  'neke': 3623,
#  'stvari': 6430,
#  'ce': 627,
#  'biti': 456,
#  'iskljucene': 2197,
#  'postavlja': 4735,
#  'model': 3352,
#  'pored': 4678,
#  'toga': 6718,
#  'mainwindowu': 3144,
#  'postavljen': 4738,
#  'novi': 3811,
#  'zavisnosti': 7570,
#  'od': 3949,
#  'mainwindows': 3143,
#  'treba': 6815,
#  'otvori': 4251,
#  'tab': 6534,
#  'ili': 1981,
#  'selektuje': 5901,
#  'vec': 7195,
#  'otvoren': 4247,
#  'param': 4329,
#  'setuje': 5958,
#  'svim': 6510,
#  'potrebnim': 4782,
#  'akcijama': 175,
#  'na': 3433,
#  'popup': 4670,
#  'meniju': 3252,
#  'graph': 1793,
#  'trenutno': 6836,
#  'trebala': 6817,
#  'izvrsi': 2407,
#  'pokrenuta': 4568,
#  'akcija': 174,
#  'graphtree': 1803,
#  'komponenti': 2736,
#  'petlja': 4395,
#  'prolazi': 5272,
#  'kroz': 2926,
#  'matrice': 3210,
#  'te': 6607,
#  'provjeravaju': 5389,
#  'elementi': 1393,
#  'istih': 2249,
#  'pozicija': 4824,
#  'jednaki': 2467,
#  'isti': 2248,
#  'klasa': 2589,
#  'predstavlja': 4957,
#  'akciju': 179,
#  'zumiranje': 7628,
#  'najbolji': 3457,
#  'moguc': 3370,
#  'prikaz': 5103,
#  'selektovanih': 5894,
#  'elemenata': 1388,
#  'mozemo': 3406,
#  'iterirati': 2280,
#  'koristeci': 2879,
#  'proxy': 5396,
#  'exggraphregister': 1478,
#  'podržava': 4509,
#  'više': 7306,
#  'registara': 5620,
#  'njih': 3757,
#  'može': 3410,
#  'čuva': 7672,
#  'grafove': 1781,
#  'gde': 1640,
#  'god': 1748,
#  'želi': 7699,
#  'ovoj': 4279,
#  'klasi': 2593,
#  'implementiran': 2026,
#  'podrazumevani': 4500,
#  'registar': 5619,
#  'grafova': 1780,
#  'podatke': 4466,
#  'ram': 5491,
#  'sve': 6499,
#  'radilo': 5473,
#  'čak': 7651,
#  'iako': 1930,
#  'konkretna': 2770,
#  'komponenta': 2733,
#  'koja': 2662,
#  'implementira': 2021,
#  'funkcionalnost': 1621,
#  'ne': 3604,
#  'postoji': 4761,
#  'sistemu': 6013,
#  'author': 342,
#  'tim': 6690,
#  'poruku': 4695,
#  'rotiramo': 5751,
#  'levo': 3020,
#  'br_mesta': 499,
#  'рад': 8178,
#  'са': 8223,
#  'истовремену': 7862,
#  'декларацију': 7769,
#  'иницијализацију': 7853,
#  'низа': 7988,
#  'колекцијску': 7881,
#  'петљу': 8072,
#  'обичнан': 8004,
#  'форматизован': 8326,
#  'испис': 7858,
#  'података': 8080,
#  'на': 7955,
#  'стандардни': 8254,
#  'излаз': 7829,
#  'коришћење': 7903,
#  'излазних': 7830,
#  'секвенци': 8245,
#  'приликом': 8144,
#  'исписа': 7859,
#  'iedge': 1955,
#  'ovaj': 4260,
#  'edge': 1358,
#  'modelu': 3355,
#  'format': 1580,
#  'po': 4436,
#  'kojem': 2665,
#  'upisuje': 7033,
#  'ssn': 6258,
#  'del': 972,
#  'boy': 496,
#  'vrsi': 7361,
#  'komunikaciju': 2743,
#  'sa': 5769,
#  'klijentom': 2602,
#  'prilikom': 5129,
#  'dodavanja': 1189,
#  'meca': 3231,
#  'radi': 5469,
#  'karakteru': 2554,
#  'spada': 6197,
#  'engleski': 1414,
#  'alfabet': 203,
#  'prepisuje': 5005,
#  'if': 1956,
#  'it': 2258,
#  'character': 673,
#  'from': 1608,
#  'the': 6656,
#  'english': 1418,
#  'alphabet': 221,
#  'except': 1459,
#  'for': 1575,
#  'is': 2180,
#  'copied': 822,
#  'svidja': 6508,
#  'nam': 3491,
#  'bude': 563,
#  'primoran': 5157,
#  'instancira': 2130,
#  'objekat': 3882,
#  'kada': 2528,
#  'zeli': 7591,
#  'sortira': 6183,
#  'tacke': 6565,
#  'podizemo': 4489,
#  'nivo': 3723,
#  'enkapsulacije': 1419,
#  'apstrakcije': 266,
#  'tako': 6580,
#  'sto': 6373,
#  'komparator': 2716,
#  'premestamo': 4998,
#  'klasu': 2596,
#  'comparatorv2': 763,
#  'tacka': 6564,
#  'osim': 4175,
#  'zelimo': 7592,
#  'obezbedimo': 3866,
#  'najvise': 3480,
#  'komparatora': 2717,
#  'put': 5435,
#  'poredjenje': 4685,
#  'dodatno': 1187,
#  'sakrili': 5802,
#  'smo': 6151,
#  'poredipoxpay': 4682,
#  'spoljasnjeg': 6227,
#  'sveta': 6504,
#  'jer': 2491,
#  'ona': 4080,
#  'sada': 5785,
#  'umetnuta': 6956,
#  'privatna': 5200,
#  'racunanje': 5461,
#  'rekurzivno': 5649,
#  'dodavanje': 1190,
#  'nove': 3810,
#  'komponente': 2735,
#  'statusbar': 6317,
#  'statusbarcontent': 6319,
#  'dodaje': 1161,
#  'sadrzaj': 5787,
#  'kraj': 2895,
#  'datoteke': 910,
#  'dodato': 1188,
#  'zbog': 7588,
#  'odigrajpotez': 3973,
#  'koristi': 2881,
#  'contains': 805,
#  'metod': 3282,
#  'prvo': 5413,
#  'generišemo': 1667,
#  'random': 5493,
#  'deklaracije': 963,
#  'funkcija': 1616,
#  'isto': 2251,
#  'naravno': 3521,
#  'gore': 1756,
#  'date': 902,
#  'host': 1909,
#  'klijent': 2597,
#  'loguje': 3107,
#  'pomoćna': 4636,
#  'return': 5706,
#  'suprotnom': 6477,
#  'sistem': 6010,
#  'željeno': 7702,
#  'stanje': 6287,
#  'constant': 799,
#  'konstanta': 2782,
#  'reprezentuje': 5674,
#  'uvodi': 7132,
#  'mora': 3384,
#  'op_puta': 4108,
#  'vraća': 7339,
#  'viewer': 7272,
#  'kontrolu': 2818,
#  'kojoj': 2670,
#  'navigator': 3577,
#  'iscrtava': 2186,
#  'reaguje': 5563,
#  'klik': 2606,
#  'prelazak': 4987,
#  'preko': 4985,
#  'dugmeta': 1308,
#  'tabu': 6559,
#  'zatvaranje': 7547,
#  'označava': 4289,
#  'desni': 1018,
#  'nad': 3439,
#  'nodom': 3786,
#  'njim': 3764,
#  'zatražen': 7542,
#  'poperti': 4661,
#  'prozor': 5397,
#  'parametri': 4340,
#  'ol': 4059,
#  'inode': 2114,
#  'nod': 3770,
#  'traži': 6812,
#  'propertz': 5318,
#  'ucitaj': 6877,
#  'op_pridruzi': 4107,
#  'generated': 1649,
#  'by': 586,
#  'javacc': 2432,
#  'do': 1130,
#  'not': 3798,
#  'edit': 1366,
#  'this': 6665,
#  'line': 3036,
#  'simplecharstream': 5994,
#  'java': 2429,
#  'version': 7230,
#  'ovo': 4277,
#  'olaksa': 4060,
#  'clone': 731,
#  'klasama': 2591,
#  'naslednicama': 3541,
#  'moze': 3405,
#  'nista': 3718,
#  'konkretnije': 2775,
#  'uradi': 7062,
#  'instancirati': 2136,
#  'consume': 803,
#  'newline': 3689,
#  'provides': 5386,
#  'common': 760,
#  'neuron': 3675,
#  'input': 2115,
#  'functions': 1615,
#  'tabmenager': 6551,
#  'popunjava': 4667,
#  'skup': 6044,
#  'tiketa': 6684,
#  'podacima': 4461,
#  'iz': 2290,
#  'xml': 7427,
#  'fajla': 1515,
#  'tickets': 6679,
#  'zatvaramo': 7545,
#  'scanner': 5853,
#  'slicno': 6076,
#  'zatvaranju': 7548,
#  'drag': 1279,
#  'srednje': 6250,
#  'dugme': 1307,
#  'krajnja': 2897,
#  'tachka': 6563,
#  'ukupna': 6932,
#  'duljina': 1313,
#  'kromosoma': 2925,
#  'jednaka': 2465,
#  'bitova': 458,
#  'pojedine': 4555,
#  'varijable': 7180,
#  'varijabli': 7181,
#  'oznčava': 4291,
#  'promenjen': 5281,
#  'flag': 1564,
#  'menjan': 3256,
#  'poslednjeg': 4717,
#  'save': 5840,
#  'igraph': 1964,
#  'kome': 2709,
#  'dirty': 1093,
#  'value': 7172,
#  'boolean': 489,
#  'true': 6848,
#  'false': 1525,
#  'definise': 951,
#  'reakciju': 5565,
#  'programa': 5246,
#  'pritisak': 5188,
#  'escape': 1437,
#  'cancel': 600,
#  'prozoru': 5400,
#  'promenljiva': 5289,
#  'nodeindex': 3776,
#  'resetuje': 5687,
#  'replace': 5663,
#  'iskljucuje': 2199,
#  'dok': 1215,
#  'potreban': 4776,
#  'zatvara': 7544,
#  'setalignment': 5933,
#  'postavice': 4731,
#  'poravnanje': 4675,
#  'unutar': 7010,
#  'elementa': 1391,
#  'argument': 287,
#  'proslediti': 5326,
#  'enum': 1425,
#  'pos': 4696,
#  'postavljanje': 4737,
#  'fill': 1549,
#  'boje': 480,
#  'bojan': 478,
#  'delić': 983,
#  'e11510': 1349,
#  'projekat': 5260,
#  'predmeta': 4953,
#  'mrežno': 3419,
#  'bazirani': 398,
#  'sistemi': 6012,
#  'sportska': 6235,
#  'kladionica': 2587,
#  'sep': 5912,
#  '20': 49,
#  '2009': 55,
#  'rezultat': 5714,
#  'rješava': 5736,
#  'lijeva': 3029,
#  'strana': 6387,
#  'niza': 3729,
#  'upisuju': 7035,
#  'brojevi': 541,
#  'pomereni': 4621,
#  'linkovi': 3047,
#  'pravimo': 4907,
#  'novu': 3828,
#  'listu': 3072,
#  'concurrentmodificationexception': 785,
#  'tip': 6695,
#  'prihvata': 5093,
#  'oldtabpanel': 4065,
#  'kloniranje': 2636,
#  'javi': 2442,
#  'jednostavan': 2480,
#  'nacin': 3435,
#  'kopiranja': 2839,
#  'objekata': 3883,
#  'koraci': 2843,
#  'implementirati': 2031,
#  'cloneable': 732,
#  'interfejs': 2154,
#  'definisati': 950,
#  'handluje': 1847,
#  'baca': 365,
#  'clonenotsupportedexception': 733,
#  'vecini': 7197,
#  'slucajeva': 6107,
#  'pozvati': 4859,
#  'natklase': 3564,
#  'lanac': 2973,
#  'pozivanja': 4839,
#  'super': 6473,
#  'nastavlja': 3554,
#  'object': 3879,
#  'memcopy': 3240,
#  'prednosti': 4954,
#  'kloniranja': 2635,
#  'jednostavno': 2483,
#  'kratak': 2902,
#  'kod': 2643,
#  'najlaksi': 3463,
#  'postojece': 4752,
#  'hijerarhije': 1885,
#  'lako': 2966,
#  'najbrzi': 3458,
#  'kopiranje': 2840,
#  'nizova': 3731,
#  'mane': 3165,
#  'dosta': 1244,
#  'sintakse': 6005,
#  'oko': 4048,
#  'poziva': 4834,
#  'videti': 7265,
#  'ispod': 2236,
#  'handlovati': 1846,
#  'exception': 1460,
#  'kastovanje': 2563,
#  'marker': 3185,
#  'moramo': 3388,
#  'rucno': 5754,
#  'deklaracija': 962,
#  'protected': 5370,
#  'public': 5424,
#  'nemamo': 3634,
#  'konstrukcijom': 2794,
#  'pozivaju': 4835,
#  'konstruktori': 2799,
#  'prekine': 4982,
#  'jedna': 2463,
#  'hijerarhiji': 1886,
#  'plitko': 4425,
#  'primer': 5141,
#  'ilustruje': 1986,
#  'inace': 2048,
#  'nasa': 3530,
#  'sadrzi': 5792,
#  'one': 4084,
#  'moraju': 3385,
#  'jos': 2513,
#  'puno': 5432,
#  'vreme': 7350,
#  'milisekundama': 3302,
#  'izmedju': 2337,
#  'menjanja': 3257,
#  'stanja': 6286,
#  'progress': 5256,
#  'bara': 384,
#  'pri': 5084,
#  'pokretanju': 4574,
#  'efekta': 1374,
#  'inicijalizaciju': 2087,
#  'promenljivih': 5292,
#  'ul': 6936,
#  'mainwindow': 3142,
#  'menu': 3260,
#  'filemenu': 1542,
#  'editmenu': 1368,
#  'selectmenu': 5882,
#  'viewmenu': 7273,
#  'addmenu': 152,
#  'settingsmenu': 5956,
#  'helpmenu': 1872,
#  'lista': 3052,
#  'prazna': 4920,
#  'otvaranja': 4245,
#  'findreplacewindow': 1556,
#  'find': 1555,
#  'grana': 1784,
#  'usmerena': 7095,
#  'unesena': 6971,
#  'cena': 644,
#  'requirement': 5682,
#  'zanima': 7510,
#  'on': 4079,
#  'pozove': 4852,
#  'znam': 7609,
#  'ruzno': 5765,
#  'polimorfan': 4594,
#  'apstraktan': 269,
#  'crtanje': 853,
#  'breakpointova': 504,
#  'selektovanog': 5899,
#  'linka': 3044,
#  'stampanje': 6276,
#  'rezultata': 5715,
#  'tj': 6706,
#  'brojeva': 538,
#  'liste': 3060,
#  'pokretanje': 4571,
#  'promeni': 5278,
#  'parametru': 4343,
#  'nizovnog': 3734,
#  'tipa': 6696,
#  'konstruktor': 2796,
#  'pravljenje': 4910,
#  'posiljke': 4709,
#  'posto': 4748,
#  'inicijalno': 2100,
#  'istom': 2254,
#  'statusu': 6324,
#  'prijem': 5101,
#  'treci': 6821,
#  'konstruktora': 2797,
#  'neophodan': 3640,
#  'program': 5245,
#  'koncept': 2747,
#  'nasleđivanja': 3544,
#  'apstraktnih': 273,
#  'sabire': 5776,
#  'petlje': 4396,
#  'negativan': 3615,
#  'povecava': 4793,
#  'brojac': 524,
#  'negativne': 3617,
#  'brojeve': 540,
#  'kom': 2695,
#  'novou': 3827,
#  'ignježdavanja': 1957,
#  'vrhu': 7355,
#  'nivou': 3725,
#  'svi': 6507,
#  'nodovi': 3789,
#  'njemu': 3752,
#  'podgrafu': 4486,
#  'td': 6606,
#  'ugnježdenja': 6895,
#  'noda': 3771,
#  'menutext': 3270,
#  'tekst': 6613,
#  'pojavljuje': 4548,
#  'izbor': 2307,
#  'prepisujemo': 5006,
#  'vrednosti': 7349,
#  'odredjuju': 4003,
#  'gustinu': 1837,
#  'grida': 1820,
#  'zoom': 7615,
#  'faktora': 1522,
#  'tablemodel': 6546,
#  'manipulaciju': 3166,
#  'tabele': 6540,
#  'pluginmanagermainwindow': 4428,
#  'prozora': 5398,
#  'visina': 7283,
#  'zoombar': 7616,
#  'kontrole': 2812,
#  'izracunaj': 2357,
#  'ao': 249,
#  'init': 2104,
#  'dobro': 1149,
#  'binarna': 438,
#  'pretraga': 5045,
#  'zahteva': 7481,
#  'znamo': 7610,
#  'poredimo': 4681,
#  'elemente': 1392,
#  'kolekciji': 2678,
#  'compareto': 767,
#  'pretvaramo': 5055,
#  'minute': 3318,
#  'sate': 5837,
#  'stemuje': 6364,
#  'reči': 5724,
#  'duže': 1325,
#  'slova': 6097,
#  'kraće': 2906,
#  '31': 82,
#  'originalnoj': 4165,
#  'implementaciji': 2016,
#  'stems': 6363,
#  'words': 7410,
#  'longer': 3117,
#  'than': 6654,
#  'letters': 3015,
#  'and': 238,
#  'shorter': 5974,
#  'per': 4378,
#  'original': 4161,
#  'implementation': 2018,
#  'одреди': 8025,
#  'нзд': 7985,
#  'за': 7798,
#  'ток': 8293,
#  'одговарајућих': 8022,
#  'позитивних': 8088,
#  'pozivanje': 4840,
#  'metode': 3285,
#  'sortiranje': 6189,
#  'početno': 4876,
#  'postavljamo': 4736,
#  'scenu': 5856,
#  'naslov': 3548,
#  'konacno': 2744,
#  'zavesu': 7565,
#  'inicijalizujemo': 2097,
#  'kolekciju': 2682,
#  'staticka': 6307,
#  'aslist': 321,
#  'vraca': 7324,
#  'arraylist': 306,
#  'prosledjene': 5328,
#  'argumente': 289,
#  'stari': 6293,
#  'scale': 5849,
#  'faktori': 1523,
#  'to': 6710,
#  'ispisuje': 2225,
#  'korisniku': 2873,
#  'celija': 631,
#  'bit': 453,
#  'slider': 6079,
#  'klizac': 2615,
#  'podeseni': 4474,
#  'jezik': 2499,
#  'interfejsa': 2155,
#  'aplikacije': 252,
#  'pociciju': 4455,
#  'kontrola': 2811,
#  'argumenta': 288,
#  'germ': 1671,
#  'nodes': 3782,
#  'argumetvalue': 292,
#  'optimalna': 4152,
#  'duzina': 1321,
#  'opruge': 4145,
#  'veze': 7246,
#  'medju': 3236,
#  'nodovima': 3790,
#  'dana': 895,
#  'mjeseèno': 3334,
#  'unese': 6968,
#  'mjesec': 3327,
#  'povlaèi': 4810,
#  'taj': 6575,
#  'uzima': 7138,
#  'dan': 894,
#  'januar': 2424,
#  'itd': 2259,
#  'oni': 4087,
#  'sortiraju': 6184,
#  'izlaz': 2324,
#  'liniju': 3042,
#  'promptom': 5301,
#  'korisno': 2876,
#  'prompt': 5299,
#  'nekog': 3627,
#  'događaja': 1212,
#  'pa': 4296,
#  'staviti': 6328,
#  'znanja': 7611,
#  'desilo': 1011,
#  'obrisan': 3917,
#  'bio': 449,
#  'aktivan': 182,
#  'prvi': 5410,
#  'valueof': 7173,
#  'promenljive': 5291,
#  'prima': 5130,
#  'njenu': 3756,
#  'stringovnu': 6412,
#  'reprezentaciju': 5673,
#  'vecinu': 7198,
#  'primitivnih': 5156,
#  'tipova': 6697,
#  'nizove': 3732,
#  'objekte': 3885,
#  'string': 6402,
#  'izracunava': 2359,
#  'kreira': 2909,
#  'što': 7697,
#  'prikazao': 5108,
#  'funkcionisao': 1624,
#  'javadoc': 2436,
#  'kad': 2527,
#  'kljucna': 2625,
#  'rec': 5574,
#  'definiciju': 938,
#  'class': 725,
#  'novog': 3818,
#  'servisa': 5928,
#  'tk': 6707,
#  'exgerm': 1473,
#  'core': 828,
#  'plugin': 4426,
#  'icomponent': 1932,
#  'name': 3493,
#  'ime': 1998,
#  'service': 5925,
#  'servis': 5927,
#  'citanje': 712,
#  'min': 3309,
#  'granicu': 1791,
#  'pomeranja': 4616,
#  'pokrece': 4563,
#  'id': 1936,
#  'naredbe': 3523,
#  'uglavnom': 6888,
#  'dobijenog': 1141,
#  'action': 136,
#  'akcije': 176,
#  'klijente': 2599,
#  'prepusta': 5014,
#  'posao': 4698,
#  'nitima': 3722,
#  'dumre': 1314,
#  'srednji': 6251,
#  'taster': 6594,
#  'main': 3140,
#  'prethodnim': 5033,
#  'zamjenjuju': 7507,
#  'mjesta': 3335,
#  'see': 5872,
#  'javax': 2441,
#  'swing': 6522,
#  'jcomponent': 2450,
#  'paintcomponent': 4298,
#  'awt': 355,
#  'graphics': 1797,
#  'prosiruje': 5321,
#  'spomenutu': 6234,
#  'iscrtavanjem': 2191,
#  'zadatom': 7459,
#  'redosledu': 5600,
#  'mrezu': 3417,
#  'selektovano': 5898,
#  'njeno': 3755,
#  'iscrtavanje': 2190,
#  'laso': 2981,
#  'shadow': 5966,
#  'ukljuceni': 6917,
#  'isprekidani': 2240,
#  'pravougaonik': 4914,
#  'handle': 1842,
#  'ove': 4270,
#  'prelomne': 4993,
#  'selektovane': 5892,
#  'selektovana': 5891,
#  'veza': 7238,
#  'code': 740,
#  'nula': 3834,
#  'ima': 1988,
#  'vrednost': 7348,
#  'ova': 4259,
#  'definisana': 942,
#  'klasna': 2594,
#  'brojanje': 530,
#  'prestupnih': 5026,
#  'godina': 1749,
#  'konaèni': 2746,
#  'kontexta': 2809,
#  'briše': 517,
#  'stvarnu': 6434,
#  'vezu': 7249,
#  'grafu': 1783,
#  'testiranje': 6646,
#  'svih': 6509,
#  '10000': 15,
#  'kraju': 2901,
#  'fino': 1561,
#  'ispise': 2222,
#  'ovdje': 4269,
#  'odabire': 3951,
#  'karta': 2556,
#  'meceva': 3232,
#  'matchlist': 3200,
#  'podrazumevana': 4498,
#  'mogucnost': 3374,
#  'ukoliko': 6928,
#  'skupa': 6045,
#  'getimage': 1689,
#  'postavi': 4730,
#  'poslednje': 4716,
#  'pravilo': 4905,
#  'racun': 5454,
#  'uneta': 6980,
#  'operacija': 4124,
#  'izabrana': 2293,
#  'debljina': 918,
#  'okvira': 4057,
#  'ukljanja': 6916,
#  'ilistener': 1982,
#  'osluškivač': 4184,
#  'registrovan': 5630,
#  'listener': 3061,
#  'uklanja': 6912,
#  'malim': 3158,
#  'slovom': 6102,
#  'sortirati': 6191,
#  'parseexception': 4352,
#  'dodat': 1179,
#  'atribut': 330,
#  'uklonjen': 6925,
#  'koga': 2660,
#  'attribute': 338,
#  'oldvalue': 4066,
#  'stara': 6291,
#  'provjeru': 5395,
#  'palindrom': 4309,
#  'учитавање': 8324,
#  'вредности': 7743,
#  'стандардног': 8255,
#  'улаза': 8305,
#  'коришћењем': 7904,
#  'класе': 7871,
#  'као': 7868,
#  'постављање': 8103,
#  'елементе': 7794,
#  'метода': 7935,
#  'arrays': 310,
#  'овом': 8018,
#  'примеру': 8151,
#  'користи': 7898,
#  'се': 8242,
#  'наредба': 7963,
#  'import': 2037,
#  'ради': 8179,
#  'краћег': 7915,
#  'записа': 7809,
#  'програма': 8159,
#  'standardni': 6281,
#  'unos': 7000,
#  'konzolu': 2827,
#  'poslednju': 4720,
#  'commandu': 758,
#  'undo': 6965,
#  'stacka': 6264,
#  'написати': 7961,
#  'јава': 8352,
#  'који': 7907,
#  'омогућује': 8034,
#  'унос': 8314,
#  'израза': 7833,
#  'постфиксном': 8105,
#  'облику': 8006,
#  'потом': 8106,
#  'израчунава': 7835,
#  'вредност': 7742,
#  'унесеног': 8313,
#  'изразу': 7834,
#  'могу': 7946,
#  'јавити': 8354,
#  'четири': 8342,
#  'основне': 8052,
#  'бинаре': 7714,
#  'операције': 8043,
#  'унарна': 8310,
#  'операција': 8042,
#  'промене': 8164,
#  'знака': 7814,
#  'израчунавањем': 7837,
#  'завршава': 7800,
#  'када': 7865,
#  'корисник': 7895,
#  'унесе': 8311,
#  'реч': 8220,
#  'функционалност': 8328,
#  'потребну': 8109,
#  'израчунавање': 7836,
#  'издвојити': 7828,
#  'посебну': 8099,
#  'класу': 7873,
#  'prime': 5134,
#  'poveæavamo': 4809,
#  'ga': 1632,
#  'naðe': 3594,
#  '__': 117,
#  'ispituje': 2233,
#  'prestupna': 5024,
#  'resetujemo': 5688,
#  'brojaèe': 533,
#  'kolonu': 2694,
#  'red': 5585,
#  'provjerava': 5388,
#  'sedmice': 5869,
#  'mjeseca': 3328,
#  'prebacuje': 4933,
#  'redu': 5605,
#  'granu': 1792,
#  'zadtim': 7469,
#  'izvornim': 2394,
#  'odredišnim': 3994,
#  'čvorom': 7679,
#  'izvorni': 2393,
#  'čvor': 7677,
#  'odredišni': 3993,
#  'novokreiranu': 3823,
#  'label4': 2959,
#  'gost': 1760,
#  'notifikuje': 3804,
#  'adminu': 163,
#  'check': 677,
#  'out': 4254,
#  'hotela': 1911,
#  'kreiranje': 2915,
#  'unijetom': 6995,
#  ...}

# %%
for comm in df.loc[df['label'] == 'Notice']['comment']:
    print(comm)
    print('\n')
# Out:
#  http stackoverflow com questions 4087468 ssn regex for 123 45 6789 or xxx xx xxxx
#
#
#  pošto smo prvo proverili da li graf postoji ovaj exception nikad ne bi trebao da bude bačen
#
#
#  ovo nikad ne treba da bude izvrseno
#
#
#  ovako ne treba raditi
#
#
#  metod integer parseint moze dovesti do izbacivanja runtimeexception izuzetka numberformatexception u slucaju da se u stringu ne nalazi ispravna string reprezentacija celog broja
#
#
#  primer 2
#
#
#  napomena 2 ako u programu postoje dve ili vise istovetnih string konstanti za njih se nece praviti zasebni objekti vec ce postojati samo jedan zbog toga za njih vraca true
#
#
#  prvi nacin metod valueof od promenljive koju prima kao argument vraca njenu stringovnu reprezentaciju radi za vecinu primitivnih tipova podataka nizove karaktera i objekte string valueof true se izracunava u true string valueof 5 5 se izracunava u 5 5
#
#
#  primer ilustruje jednostavnu primenu metoda split koji razbija string na niz podstringova a za razdvajanje koristi zadati string
#
#
#  nacin 3 ali zapravo mozemo i direktno vratiti sabiranje koje ce se implicitno kastovati u izraz zbog povratne vrednosti funkcije
#
#
#  greska pri kompilaciji jer implicitno kastovanje proverava da li moze da se izvrsi kastovanje povrsina p duz
#
#
#  izbacuje izuzetak arithmeticexception
#
#
#  nepoznato
#
#
#  opcije
#
#
#  zbog grešaka sa eclipse om ne mogu da riješim nikako zašto neæe da pokrene connectfour veæ pokrene opet tictactoe
#
#
#  0 rock 1 paper 2 scissors 1 0 2 2 1 0 0 2 1
#
#
#  note dodati konstante po potrebi
#
#
#  ostavljeno za eventualno kasnije koriscenje override public boolean iselementat point2d pos link link link element system out println usao u iselementat return getshape contains pos getx link getsource getposition getx pos gety link getsource getposition gety
#
#
#  for i
#
#
#  i centralna celija velicina susedstva j celija za proveru
#
#
#  ov specificne metode mozda izbaciti i ostaviti samo opstem a uscitavanje rditi sa kastovanjem s
#
#
#  pravimo listu za jezik ukoliko vec ne postoji napomena ovo je izuzetno bitan detalj svaki jezik u mapi morati imati sopstvenu listu
#
#
#  iz nikola 5 18 05 2019 14 31 predlog izmene interfejsa
#
#
# int 4nijeindetifikator ne može početi brojem ili nekim drugim znakom int nije identifikator ne može imati prazno mesto crticu ampersend zarez tačku itd
#
#
# nije preporučljivo da identifikator počinje velikim slovom
#
#
# ovako je bolje
#
#
# 10 zagradama mozemo promeniti podrazumevani prioritet operatora
#
#
# true false true true true
#
#
# 1 11111101 3 desni shift vodi racuna o znaku
#
#
# uslovni operator
#
#
# podrazumevana osnova broja je dekadna
#
#
# podrazumevani ispis je u dekadnoj osnovi tako da je rezultat ispisa broj 23
#
#
# najmanji dozvoljeni broj ovog tipa podataka
#
#
# ispisuje neki pozitivan broj dakle potkoračenje
#
#
# char tip podataka je specifičan jer ima dvostruku reprezentaciju
#
#
# celobrojni deo se može izostaviti i tada se podrazumeva da iznosti 0
#
#
# ispisuje 3 553535300003e7 što je tačan broj
#
#
# objektnitip je korisnicki definisani referentni tip koji je implicitni potomak tipa object
#
#
# putem tačka notacije može se pristupiti unutrašnjoj promenljivoj koja se zove vrednost
#
#
# dve istoiemne promenljive u dva nepreklapajuca opsega su dozvoljene
#
#
#  telo klase je blok
#
#
# jos jedan suvisan blok java kompajler se ne buni
#
#
#  nakon cekanja je moguce nastaviti neku drugu aktivnost ova tehnika se koristi u visenitnom programiranje jer je potrebno neko drugi da postavi uslov jer to ne moze da se uradi iz ove funkcije to znaci da je u ovom programu postignut efekat beskonacne petlje pa je program potrebno ekspiclitno zaustaviti
#
#
#  s1 dobija vrednost 7 jer se na 1 dodaje 6 a s vrednost 12 jer se na 5 dodaje 7
#
#
# podrazumevana mogucnost ukoliko i nije iz skupa vrednosti 0 1 2 3
#
#
#  написати јава програм који омогућује да се оформи низ дате димензије да сви чланови низа добију унаред задату вредност и да се потом применом бројачког for циклуса прикажу вредности свих чланова низа
#
#
#  student smera indeks 17 2012 je iz predmeta 4 dobio ocenu 7
#
#
#  student r smera indeks 25 2012 je iz predmeta 1 dobio ocenu 6
#
#
#  написати јава програм који пребројава елементе у низу бројева из интервала 1 10 и приказује их у бројчаном облику и у облику хистограма пренос вредности између позивајућег и позваног метода је реализован преко глобалних променљивих
#
#
#  користe се приватна поља користе се јавни методи приступа за поља клесе tacka
#
#
#  program pokrenuti sa opcijom virtulene masine ea
#
#
#  banka transfer naracun saracun iznos deadlock
#
#
#  slede primeri kako mozemo citati sa standardnog ulaza
#
#
#  karakteri su jedan od primitivnih tipova koji postoje u javi kodirani su koriscenjem unicode kodiranja da mozemo i cirilicu da koristimo
#
#
#  klasa math sadrzi vist statickih funckija vezanih za matematiku sledi par primera
#
#
#  primer 3
#
#
#  ne zatvaramo scanner sc close
#
#
#  sortiramo napomena ne moramo uvek da importujemo klasu mozemo jednostavno navesti njeno puno ime dakle u paketu java nalazi se paket util koji sadrzi klasu arrays mehanizam klasa i paketa ce biti jasniji u narednim nedeljama
#
#
#  alternativno mozemo ulancavati pozive metoda append sb append input append
#
#
#  zamislimo da pravimo tetris potrebna nam je rotacija bloka ako blok cuvamo u matrici onda nam u stvari treba rotacija matrice matricu mozemo trivijalo rotirati koristeci pomocni niz ili matricu ali rotacija matrice u mestu bez pomocnih nizova matrica nije ocigledna sledi primer koji implementira rotaciju matrice u mestu vazan uslov ne mozemo rotirati matricu u mesto ukoliko joj broj vrsti i kolona nije jednak u kodu koji sledi nije vrsena provera oko dimenzija matrice pretpostavlja se da su jednake autorova opaska procitati posle gledanja koda kodovi za obrtanje vrsti i kolona bi se mogli apstrahovati jednom funkcijom i time rasteretiti funkcije rotateleft i rotateright no nije neophodno komplikovati dalje
#
#
#  ne moramo raditi nista no mozemo ispisati nesto na stdout radi ilustracije
#
#
#  pravimo funkciju koja poredi tacke primetimo da ova funkcija poredi objekte this i t koji tu tacke funkcija je jako slicna onoj koju poseduje klasa string
#
#
#  kada se poziva konstruktor sigurni smo da se instancira objekat klase kojoj konstruktor pripada to je pravi trenutak da inkrementiramo brojac objekata
#
#
#  umesto this new tacka 0 0 a b c bolje je navedeno jer instanciramo jednu tacku manje new tacka 0 0 bi bio privremeni objekat koji se prosledjuje konstruktoru nadklase a konstruktor nadklase pravi sopstvenu kopiju od privremenog objekta java kompilator bi ovo trebalo da optimizuje ali svejedno je lepo primetiti
#
#
#  staticki inicijalizacioni blok sib omogucava da inicijalizujemo kompleksnije staticke promenljive kada nam nije dovoljna deklaracija sa inicijalizacijom onda promenljivu mozemo inicijalizovati u sib u sib se izvrsava pri pokretanju programa odnosno izvrsava se jednom dakle polja ne mozemo inicijalizovati u sib u
#
#
#  nije greska u kompilaciji ali jeste greska u fazi izvrsavanja sto je losije od prethodnog povrsina p povrsina duz system out println p getpovrsina
#
#
#  kloniranje u javi je jednostavan nacin kopiranja objekata koraci implementirati cloneable interfejs definisati clone metod koji handluje ili baca clonenotsupportedexception u vecini slucajeva pozvati clone metod natklase lanac pozivanja super clone se nastavlja do object clone koji vrsi memcopy prednosti kloniranja jednostavno kratak kod najlaksi nacin za vec postojece hijerarhije lako se dodaje metod clone najbrzi nacin za kopiranje nizova mane kloniranja dosta sintakse oko poziva clone videti ispod definisati metod handlovati exception i kastovanje cloneable je marker interfejs i moramo rucno implementirati clone ne postoji deklaracija object clone je protected ne public nemamo kontrolu nad konstrukcijom jer se ne pozivaju konstruktori super clone lanac moze da se prekine ako jedna klasa u hijerarhiji ne implementira clone object clone radi plitko kopiranje sto ovaj primer ilustruje inace moramo rucno pozvati clone za sve klase koje nasa klasa sadrzi i one moraju implementirati cloneable i jos puno toga
#
#
#  throw new arrayindexoutofboundsexception ukoliko navedemo string u konstruktoru taj string se vraca kada se nad izuzetkom pozove metod getmessage
#
#
#  java 8 poseduje klasu optional t koja funkcionise slicno poput nase klase https www baeldung com java optional
#
#
#  struktura podataka map nam omogucava da napravimo preslikavanje k v gde su k kljuc eng key v vrednost eng value ovakva struktura podataka se u praksi intenzivno koristi citanje podataka iz baza podataka cuvanje retkih matrica cuvanje grafova
#
#
#  hashmap je implementacija mape preko hes tabele neophodno je da za kljuceve budu predefinisani metodi equals i hashcode iz klase object hes kod odredjuje mesto u tabeli gde ce element biti smesten za implementaciju ovih metoda mora biti ispunjen uslov da ako metod equals vrati true za dva objekta onda metod hashcode mora vratiti istu vrednost za oba obrnuto ne vazi moze da se desi da equals vrati false za dva objekta a da im hes kodovi budu jednaki tu pojavu nazivamo kolizija resenje kolizije koje nudi ova implementacija je odrzavanje povezane liste na mestima u tabeli gde je doslo do kolizije
#
#
#  primetimo da u spoljasnjem svetu izmene u klasi tacka se sada ne odrazavaju odnosno korisnik ne zna kako smo implementirali komparator i kod iz proslog paketa ne moramo uopste da menjamo
#
#
#  implementacija preko komparatora bi bila slicna osim sto bi this zamenili sa o1 referenca na prvi objekat a o sa o2 referenca na drugi objekat za slucaj da je u pitanju komplikovanija logika nekada nije na odmet ipak razmotriti da se napravi odvojena klasa za komparator umesto da se pravi anonimna klasa
#
#
#  zasto je path interfejs postoji vise fajl sistema pozivanjem staticke funkcije get java nam vraca pravi path objekat u zavisnosti od fajl sistema na kojem se program izvrsava ovo donekle ilustruje pojam enkapsulacije programer ne mora brinuti o tim detaljima vec dobija uslugu koju pruzaju klase za rad sa putanjama a kod se potencijalno drugacije izvrsava u zavisnosti od operativnog sistema na kojem se program pokrece
#
#
#  da li postoji bolji brzi kraci optimalan redosled operacija tako da pipeline niz transformacija ucini manje posla
#
#
#  p p v p v rv p rv v v rv rv
#
#
#  milošević pravi grešku kod pevasmo
#
#
#  poèetni dan u mjesecu je stavljen za 1 mada se može napraviti i da se mijenja tj da korisnik unese dan
#
#
#  deprecated see getendcolumn
#
#
#  note dodati instance stanja po potrebi
#
#
#  deo koda preuzet s neta bez sustinskog razumevanja sta isti radi
#
#
#  provides method to reads stock data from the socket see http neuroph sourceforge net tutorials stockmarketpredictiontutorial html author dr v steinhauer
#
#
#  compareto drugi nacin
#
#
#  treci nacin isti kao drugi ali koristi lambda sintaksu da se skrati zapis igre sort videoigra a videoigra b return a getime compareto b getime
#
#
# međutim moguće je broj zapisati i u heksadekadnoj ili oktalnoj osnovi npr dekadni u heksadekdanoj
#
#
#  pokretanje 2 metod moze da vrati vrednost primitivnog tipa kao rezultat
#
#
#  pokretanje 1 metod moze da promeni neki od elemenata u parametru nizovnog tipa
#
#
#  pokretanje 2 metod ne moze objektnom parametru trajno pridruziti neki drugi objekat
#
#
#  dobro ali moze i bolje duz string o tacka t1 tacka t2 oznaka o a new tacka t1 x t1 y t1 oznaka b new tacka t2 x t2 y t2 oznaka
#
#
#  bolje je hkvalue broj
#
#
#  ovde bi isla logika za kontrolu jmbg
#
#
#  ovako treba raditi
#
#
#  napomena string nije primitivni tip poput int double i ostalih vec se ubraja u klasni tip no string je poseban u javi vise o njemu na narednim casovima
#
#
#  kako mozemo translirati oblik nase klase iz hijerarhije oblik ne nude tu funkcionalnost ali mozemo izvrsiti translaciju koristeci klasu tacka
#
#
#  nacin 1 mozemo eksplicitno kastovati u izraz posto funkcija vraca izraz izraz i izraz s return i
#
#
#  isti od java7 standardna efekat mozemo postici sledecom konstrukcijom
#
#
#  ukoliko zelimo da uhvatimo sve ostale izuzetke koji nisu navedeni u prethodnim catch konstrukcijama mozemo da navedemo exception koji hvata sve izuzetke blok catch u sustini radi poredjenje koristeci operator instanceof pogledati primer pod komentarom kako bi se to vestacki imitirali
#
#
#  koliko razlicitih praznih vrednosti postoji za konkretan tip t tacno jedna tako da mozemo da je instanciramo samo jednom skriveno od korisnika i izbegnemo suvisna instanciranja sustinski istog objekta tokom rada programa tehnicki detalj kako kompilator treba da nacini da vrednost empty dele razne klase u zavisnosti od tipa t koristimo wildcard koji oznacava da se dopusta bilo koji tip
#
#
#  skup predstavlja strukturu podataka inspirisanu matematickim skupom ono sto je od velikog znacaja za skup je da ne postoje duplikati u njemu jedna od cescih implementija skupe je preko stabla duplikati se izbegavaju tako sto pri dodavanju ukoliko se pronadje element koji se dodaje odustaje se od dodavanja a inace se dodaje slozenost ove operacija zavisi linearno od visine h stabla o h java poseduje interfejs set i nekoliko implementacija za skup na kursu cemo najcesce koristiti implementaciju skupa preko stabla odnosno treeset
#
#
#  zakljucak 1 pri obilasku kroz skup brojevi bivaju prikazani rastuce ocekivano kada znamo da se koristi stablo 2 ne postoje duplikati sto je i svojstvo skupa
#
#
#  liste i ostale genericke kolekcije u javi ce biti obradjeni narednih casova za sada dovoljno nam je da znamo da iteriramo kroz listu standardcharsets predstavlja klasu kojoj mozemo pronaci kodiranje koje nam je potrebno na kursu cemo uvek specifikovati utf_8
#
#
#  kada korisnik unese koji je mjesec npr 3 on uzima iz niza mjesec 3 i znamo da je onda mart jer je na poziciji 3
#
#
#  uz pomoc http stackoverflow com questions 31523419 java print a short as binary with all 16 bits
#
#
#  niz nam sluzi kao brojac ako dobijemo random broj npr 2 onda æe se poveæati niz 2 za 1
#
#
#  https plumbr eu outofmemoryerror requested array size exceeds vm limit
#
#
#  ako želiš provjeriti koje se rijeci ponavljaju iste u obje reèenice samo obriši ovo dole else break i to je to
#
#
#  ideju potpomogao kolega i stranica http javaconceptoftheday com how to create pyramid of numbers in java
#
#
#  nadamo se da se nece desiti
#
#
#  u ovaj kod ne zalaziti jer jos ne radi kako treba
#
#
#  return vraca sve meceve u sistemu istu stvar radi metoda getallmatches ne znam zasto postoje obe greska
#
#
#  da li ovd etreba staviti da proverava i da li se koristi ovaj uslov ili staviti da uslov bude automatski samo s ajaako malom vrednoscu za errorchange doule minvalue
#
#
#  написати јава програм који за унесене бројеве врши рачунање биномног коефицијента на два начина рекурзивно и динамичким програмирањем и приказује добијене резултате и времена извршавања за оба начина
#
#
#  написати јава програм који омогућује погађање замишљеног псеудослучајног целог броја из датог интервала крајеви интервала у ком се налази замишљени број се дају преко командне линије а ако нису дати на тај начин онда се очитавају са улаза одређивање броја који се погађа реализовати на више начина метод за одређивање се такође даје преко командне линије а ако није дат на тај начин онда се очитавају са улаза
#
#
#  написати јава програм који пребројава елементе у низу бројева из интервала 1 10 и приказује их у бројчаном облику и у облику хистограма
#
#
#  написати јава програм који за низ оцена студената одређује њихове просечне оцене по смеру и по предмету низ садржи оцене а индекси су редом ознака смера 0 7 кодира смер м н в р л и аа аф број индекса година уписа умањена за 2000 и ознака предмета тј редни број предмета у списку предмета оцене су у опсегу 5 10 уколико дати студент није полагао дати предмет онада ће члан низа индексиран четворком смер година индекс предмет бити 1
#
#
#  написати јава програм који омогућује да се 1 оформи низ ниски произвољне димензије коју одређује корисник такав да сви чланови низа добију унаред задату вредност коју такође задаје корисник 2 оформи низ реалних бројева произвољне димензије димензију низа одређује корисник и да сви чланови низа добију унаред задату вредност коју такође задаје корисник
#
#
#  написати јава програм који омогућује да се коришћењем дводимензионалног низа реализује приказ паскаловог троугла број врста паскаловог троугла се учитава са улаза
#
#
#  написати јава програм који омогућује унос израза у постфиксном облику и потом израчунава вредност унесеног израза у изразу се могу јавити четири основне бинаре операције и унарна операција промене знака са израчунавањем се завршава када корисник унесе реч kraj функционалност потребну за израчунавање израза издвојити у посебну класу
#
#
#  ovo nije dobro
#
#
#  написати јава програм који омогућује да се секвенца ниски прикажe у обрнутом редоследу и то коришћењем стека који садржи ниске структура за стек ниски која се користе у решењу је издвојена у посебну класу стек ниски је реализован преко низа и може да расте по потреби
#
#
#  korisne internet adrese http www javapractices com topic topicaction do id 229 http www codingdiary com developers developers diary javaapi java lang samplecode setuncaughtexceptionhandlerexamplecode html http www javamex com tutorials exceptions exceptions_uncaught_handler shtml
#
#
#  uocite pravilnost medju promenljivama pozovite ih redom u funkciji art koristeci funkciju println pokrenuti program
#
#
#  dodeljujemo joj vrednost napomena new scanner system in ce biti objasnjen nesto kasnije ukratko pravi scanner koji ce citati sa standardnog ulaza
#
#
#  ukoliko zelimo da proverimo da li je korisnik uneo podatak koji je tipa koji zelimo da unesemo mozemo koristiti metode klase scanner koji pocinju sa has
#
#
#  postoji i ugradjena funkcija fiiiii math toradians fiiiii
#
#
#  kada scanner vezujemo na standardni ulaz necemo ga zatvarati jer ce to zatvarati standardni ulaz tako da nas program ne moze da ga koristi na dalje eventualno mozemo ga zatvoriti na samom kraju programa kada smo sigurni da nam vise nece trebati standardni ulaz
#
#
#  evo primera kako mozemo napraviti globalnu promenljivu primetimo da je mozemo inicijalizovati takodje
#
#
#  stringove poredimo koristeci metod equals ili metod equalsignorecase napomena 1 stringove ne smemo porediti koristeci operator osim u slucaju navedenom u napomeni 2 jer on ne cita sta pise u stringovima nego poredi da li su jednake reference promenljivih string je klasni tip
#
#
#  metod replaceall radi isto sto i metod replace samo sto podstring koji se zamenjuje moze biti zadat koristeci naprednije tehnike tj regularne izraze
#
#
#  za razdvajanje koristimo tacku razmak ili zapetu kako ima dva delimitera jedan do drugog zapeta i razmak posle izraze izmedju njih ce se kao izdvojeni podstring naci prazan string
#
#
#  ako zelimo da sacuvamo staru tacku pre translacije ne mozemo sa tacka c1 krug getcentar vec moramo da dobijemo kopiju tacke sa obzirom na to da joj sledi promena nakon translacije
#
#
#  kod se trivijalno moze naciniti bezbednim po niti sa public synchronized logger get no to vec izlazi iz domena kursa vise o tome na kursu razvoja softvera
#
#
#  nacin 2 mozemo i javu naterati da kast uradi za nas implicitno izraz i s return i
#
#
#  primetimo da objekat na koji ukazuje referenca b mozemo dva puta iskoristiti jer se broj ne moze promeniti na ovaj nacin mozemo ustedeti na memoriji
#
#
#  referenca c koja referise na objekat klase covek mozemo kastovati na nesto sto implementira interfejs srpskijezik na ovaj nacin mozemo omoguciti polimorfno izvrsavanje metoda a usput korisnika osloboditi brige o tome sa kojom klasom radi ono sto je za korisnika bitno je koje to funkcije pruza interfejs
#
#
#  napomena skupo je stalno pozivati values metod u ozbiljnoj implementaciji bi se kesirao rezultat videti naredni primer
#
#
#  kada nam funkcija vraca opcionu vrednost to je jasan indikator da njen poziv moze biti neuspesan i da je vrlo vazno da proverimo dobijeni rezultat pitanje za vas koja je mana nase klase opcionavrednost hint kako cete saznati do kakve greske je doslo domaci napravite klasu opcionavrednostsagreskom koja dodatno sadrzi informaciju o gresci koja se desila na primer ima metod error koje vraca poruku o gresci
#
#
#  cesto je korisno imati staticke funkcije koje ulepsavaju interfejs za koriscenje i daju citljiviji kod ova funkcija se koristi da napravi opcionu vrednost pri cemu direktno poziva nas privatni konstruktor koji namece uslov da referenca vrednost nije null i ako jeste rusi program ovako radi i java util optional
#
#
#  skupovi u javi omogucavaju i skupovne operacije no skupovne operacije nisu date kao metodi eksplicitno sledi nekoliko primera njihove upotrebe https docs oracle com javase tutorial collections interfaces set html
#
#
#  sortiranje mozemo izvrsiti i nad nasim klasama no bitno je da definisemo kako se porede dve instance nase klase jedan od nacina je da klasa tacka implementira interfejs comparable tacka cime je duzna da definise metod compareto
#
#
#  ovi oblici se ne javljaju u arxiv radu oni su preuzeti iz koda miloševićevog ličnog veb sajta www inspiratron org these forms do not appear in the arxiv paper they were taken from the code of milošević s personal website www inspiratron org
#
#
#  lista se moze ispisati na standardni izlaz i na sledeci nacin tostring metod se poziva implicitno

# %%
df
# Out:
#      NaturalLanguageID ProgrammingLanguageName                   RepoID  \
# 0                   SR                    Java  BILD-IT-Advanced-master
# 1                   SR                    Java  BILD-IT-Advanced-master
# 2                   SR                    Java  BILD-IT-Advanced-master
# 3                   SR                    Java  BILD-IT-Advanced-master
# 4                   SR                    Java  BILD-IT-Advanced-master
# ...                ...                     ...                      ...
# 4705                SR                    Java              RAUM-master
# 4706                SR                    Java               SBZ-master
# 4707                SR                    Java        SCStemmers-master
# 4708                SR                    Java        SCStemmers-master
# 4709                SR                    Java        SCStemmers-master
#
#                                                SourceID  \
# 0       src\grupniProjekat_02_03_2016\SearchEngine.java
# 1       src\grupniProjekat_02_03_2016\SearchEngine.java
# 2       src\grupniProjekat_02_03_2016\SearchEngine.java
# 3       src\grupniProjekat_02_03_2016\SearchEngine.java
# 4       src\grupniProjekat_02_03_2016\SearchEngine.java
# ...                                                 ...
# 4705                                      funkcija.java
# 4706  drools-spring-v2-app\src\main\java\drools\spri...
# 4707       src\weka\core\stemmers\MilosevicStemmer.java
# 4708       src\weka\core\stemmers\MilosevicStemmer.java
# 4709         src\weka\core\stemmers\SerbianStemmer.java
#
#                                               CommentID  \
# 0     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 1     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 2     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 3     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# 4     BILD-IT-Advanced-master/src\grupniProjekat_02_...
# ...                                                 ...
# 4705                      RAUM-master/funkcija.java/294
# 4706  SBZ-master/drools-spring-v2-app\src\main\java\...
# 4707  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4708  SCStemmers-master/src\weka\core\stemmers\Milos...
# 4709  SCStemmers-master/src\weka\core\stemmers\Serbi...
#
#                                                 comment              label
# 0             ispisujemo poruku da je drajver loadovan   Functional-Inline
# 1                    ispis država za uneseni kontinent   Functional-Inline
# 2                                         slanje upute   Functional-Inline
# 3          ispis gradova koji pocinju odreðenim slovom   Functional-Inline
# 4                                    hvatalica grešaka   Functional-Inline
# ...                                                 ...                ...
# 4705           sad je podfunkcija oblika funkcija broj   Functional-Inline
# 4706  racun setoriginalnaukupnacena racundto getorig...               Code
# 4707   rečnik koji se koristi za normalizovanje čest...  Functional-Inline
# 4708   očuvava kapitalizaciju na početku rečenice pr...  Functional-Inline
# 4709   dužina u karakterima najdužeg sufiksnog pravi...  Functional-Inline
#
# [4710 rows x 7 columns]
